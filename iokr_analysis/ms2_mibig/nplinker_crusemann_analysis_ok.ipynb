# %%
# Running at commit 30e3836987dcf62c37fc47f0115dc614710fe51b

# %%
# %reload_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
import os
import numpy
import csv


from nplinker import nplinker
from nplinker import logconfig
logconfig.LogConfig.setLogLevel('DEBUG') # 'INFO' is a lot less spammy
from nplinker.scoring import IOKR
# Out:
# ['/home/grimur/miniconda2/envs/jupyter-py3/lib/python3.7/site-packages/cdk_pywrapper']
# starting server process

# %%
# Load the data into the NPLinker framework

# %%
nplinker_data_path = '/home/grimur/data-crusemann/nplinker_crusemann_20200131/crusemann_new.toml'
gnps_spectrum_file = "/home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/clusterinfosummarygroup_attributes_withIDs_withcomponentID/b270f7e260f34e808ead3f642784b672.tsv"
mibig_molecular_structures = '/home/grimur/_iokr/data/mibig/compunds_structures_2.0.csv'

# %%
npl = nplinker.NPLinker(nplinker_data_path)
# Out:
# 16:06:35 [DEBUG] config.py:71, Parsing default config file: /home/grimur/.config/nplinker/nplinker.toml
# 16:06:35 [DEBUG] config.py:74, Loading user config /home/grimur/data-crusemann/nplinker_crusemann_20200131/crusemann_new.toml
# 16:06:35 [INFO] config.py:106, Loading from local data in directory /home/grimur/data-crusemann/nplinker_crusemann_26112019
# 16:06:35 [DEBUG] loader.py:129, DatasetLoader(/home/grimur/data-crusemann/nplinker_crusemann_26112019, , False)
# 16:06:35 [DEBUG] nplinker.py:119, Enabled scoring method: metcalf
# 16:06:35 [DEBUG] nplinker.py:119, Enabled scoring method: testscore
# 16:06:35 [DEBUG] nplinker.py:119, Enabled scoring method: rosetta

# %%
npl.load_data()
# Out:
# 16:06:39 [DEBUG] nplinker.py:240, load_data (normal case, full load, met_only=False)
# 16:06:39 [WARNING] loader.py:31, WARNING: unable to find extra_nodes_file in path "/home/grimur/data-crusemann/nplinker_crusemann_26112019/quantification_table_reformatted/*.csv"
# 16:06:39 [WARNING] loader.py:31, WARNING: unable to find metadata_table_file in path "/home/grimur/data-crusemann/nplinker_crusemann_26112019/metadata_table/metadata_table*.txt"
# 16:06:39 [WARNING] loader.py:31, WARNING: unable to find quantification_table_file in path "/home/grimur/data-crusemann/nplinker_crusemann_26112019/quantification_table/quantification_table*.csv"
# 16:06:39 [INFO] loader.py:448, Loaded global strain IDs (162 total)
# 16:06:39 [INFO] loader.py:459, Loaded dataset strain IDs (162 total)
# 16:06:40 [INFO] metabolomics.py:634, 6246 molecules parsed from MGF file
# 16:06:41 [DEBUG] metabolomics.py:331, loading edges file: /home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/networkedges_selfloop/865b124c09b44db78c7d4c296a57d9ea.pairsinfo [6246 spectra from MGF]
# 16:06:41 [DEBUG] metabolomics.py:644, Nodes_file: /home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/clusterinfosummarygroup_attributes_withIDs_withcomponentID/b270f7e260f34e808ead3f642784b672.tsv, quant_table_exists?: True
# 16:06:41 [INFO] metabolomics.py:651, Found older-style GNPS dataset, no quantification table
# 16:06:41 [WARNING] metabolomics.py:517, Unknown strain: neg-3-Me.mzXML for cluster index 110002
# 16:06:41 [WARNING] metabolomics.py:517, Unknown str
# 16:06:41 [WARNING] metabolomics.py:517, Unknown strain: 29a.mzXML for cluster index 59110
# 16:06:41 [WARNING] metabolomics.py:517, Unknown strain: 29c.mzXML for cluster index 59110
# 16:06:41 [WARNING] metabolomics.py:517, Unknown strain: 27b.mzXML for cluster index 59110
# 16:06:41 [WARNING] metabolomics.py:517, Unknown strain: 12b.mzXML for cluster index 93250
# 16:06:41 [WARNING] metabolomics.py:532, 81 unknown strains were detected a total of 8194 times
# 16:06:41 [DEBUG] metabolomics.py:692, make_families: 494 molams + 2600 singletons
# 16:06:41 [WARNING] loader.py:427, Writing unknown strains from METABOLOMICS data to /home/grimur/data-crusemann/nplinker_crusemann_26112019/unknown_strains_met.csv
# 16:06:41 [INFO] loader.py:434, Loading provided annotation files (/home/grimur/data-crusemann/nplinker_crusemann_26112019/DB_result)
# 16:06:41 [DEBUG] annotations.py:57, Parsed 0 annotations configuration entries
# 16:06:41 [DEBUG] annotations.py:65, Found 0 annotations .tsv files in /home/grimur/data-crusemann/nplinker_crusemann_26112019/DB_result
# 16:06:41 [DEBUG] loader.py:298, Collecting .gbk files (and possibly renaming)
# 16:06:41 [DEBUG] loader.py:317, .gbk collection took 0.163s
# 16:06:41 [INFO] loader.py:318, 0/3435 .gbk files were renamed to remove spaces!
# 16:06:41 [DEBUG] loader.py:327, make_mibig_bgc_dict(/home/grimur/data-crusemann/nplinker_crusemann_26112019/mibig_json)
# 16:06:41 [INFO] genomics.py:384, Found 1816 MiBIG json files
# 16:06:44 [DEBUG] loader.py:329, mibig_bgc_dict has 1816 entries
# 16:06:44 [DEBUG] loader.py:389, Generating antiSMASH filename cache...
# 16:06:44 [DEBUG] loader.py:398, Cache generation took 0.012s
# 16:06:44 [DEBUG] loader.py:400, loadBGC_from_cluster_files(antismash_dir=/home/grimur/iokr_verify_data/crusemann/antismash, delimiters=['.', '_', '-'])
# 16:06:44 [INFO] genomics.py:190, Using antiSMASH filename delimiters ['.', '_', '-']
# 16:06:44 [INFO] genomics.py:291, # MiBIG BGCs = 0, non-MiBIG BGCS = 5132, total bgcs = 5132, GCFs = 454, strains=1978
# 16:06:44 [INFO] genomics.py:348, Filtering MiBIG BGCs: removing 0 GCFs and 0 BGCs
# 16:06:44 [INFO] genomics.py:298, # after filtering, total bgcs = 3316, GCFs = 454, strains=162
# 16:06:44 [DEBUG] genomics.py:302, Loading .network files
# 16:06:44 [INFO] loader.py:251, Strains filtered down to total of 118
# 16:06:44 [DEBUG] nplinker.py:264, Generating lookup tables: genomics
# 16:06:44 [DEBUG] nplinker.py:276, Generating lookup tables: metabolomics
# 16:06:44 [DEBUG] nplinker.py:285, load_data: completed
# True

# %%
# Assmeble spectrum-to-strains mapping from GNPS data

# %%
spectra_to_strains = {}
with open(gnps_spectrum_file, 'r') as f:
    r = csv.reader(f, delimiter="\t")
    header = next(r)
    id_column = header.index('cluster index')
    strain_columns = [x for x in range(len(header)) if header[x].startswith('C') and len(header[x]) == 6]
    for line in r:
        spectrum_id = line[id_column]
        member_strains = [header[x] for x in range(len(line)) if line[x] != '0' and x in strain_columns]
        spectra_to_strains[int(spectrum_id)] = member_strains

# %%
# Assign known_cluster_blast hits to BGCs

# %%
from nplinker.parsers.kcb import KCBParser

# %%
kkb_bgc_hits = {}
for bgc in npl.bgcs:
    kcb_filename = KCBParser.get_kcb_filename_from_bgc(bgc)
    kcb_parser = KCBParser(kcb_filename)
    hits = []
    for mibig_id, hit in kcb_parser.hits.items():
        score = numpy.sum([x['blast_score'] for x in hit['individual_hits']])
        hits.append((mibig_id, score))
    if len(hits) > 0:
        kkb_bgc_hits[bgc] = hits

# %%
print('BGCs with KKB hits: {}'.format(len(kkb_bgc_hits)))
# Should be 2808
# Out:
# BGCs with KKB hits: 2808

# %%
# Define the links to look for
# These are the links from the paired data platform - so, _verified_ links!!!

# %%
established_links = [
    ('CNS205', 'BGC0000827', 206),
    ('CNS205', 'BGC0000333', 489),
    ('CNB440', 'BGC0000940', 25),
    ('CNB440', 'BGC0000241', 381),
    ('CNT005', 'BGC0001228', 492),
    ('CNS205', 'BGC0000137', 353),
    ('CNS205', 'BGC0000137', 358),
    ('CNS237', 'BGC0001830', 309)
]

# %%
established_link_objects = []
for bgc, kkb_hits in kkb_bgc_hits.items():
    for strain_id, mibig_id, molfam_id in established_links:
        if strain_id == bgc.strain.id or strain_id in bgc.strain.aliases:
            if mibig_id in [x[0] for x in kkb_hits if x[1] > 10000]:
                for molecular_family in npl.molfams:
                    if molecular_family.family_id == molfam_id:
                        for spectrum in molecular_family.spectra:
                            # If we want to do this properly (i.e. using the strain objects on the spectra themselves) then this is broken!
                            if strain_id not in spectra_to_strains[spectrum.spectrum_id]:
                                continue
                            print(strain_id, bgc.id, mibig_id, spectrum.spectrum_id)
                            established_link_objects.append((bgc, spectrum))
# Out:
# CNS205 394 BGC0000137 72702
# CNS205 394 BGC0000137 72970
# CNS205 394 BGC0000137 73005
# CNS205 394 BGC0000137 70606
# CNS205 394 BGC0000137 75146
# CNS205 394 BGC0000137 75653
# CNS205 711 BGC0000137 72702
# CNS205 711 BGC0000137 72970
# CNS205 711 BGC0000137 73005
# CNS205 711 BGC0000137 70606
# CNS205 711 BGC0000137 75146
# CNS205 711 BGC0000137 75653
# CNS205 739 BGC0000333 120697
# CNS205 739 BGC0000333 121052
# CNS205 739 BGC0000333 121600
# CNS205 739 BGC0000333 122023
# CNT005 990 BGC0001228 123724
# CNT005 990 BGC0001228 123881
# CNT005 990 BGC0001228 123903
# CNS205 1642 BGC0000827 41257
# CNS205 1642 BGC0000827 41544
# CNS205 1642 BGC0000827 44160
# CNS205 1642 BGC0000827 44161
# CNS205 1642 BGC0000827 44982
# CNS237 2104 BGC0001830 58728
# CNS237 2104 BGC0001830 62174
# CNS237 2104 BGC0001830 63507
# CNS237 2104 BGC0001830 63775
# CNS237 2104 BGC0001830 65471
# CNS237 2104 BGC0001830 66182
# CNS237 2104 BGC0001830 66400
# CNS237 2104 BGC0001830 67887
# CNS237 2104 BGC0001830 68743
# CNS237 2104 BGC0001830 93193
# CNS237 2104 BGC0001830 99743
# CNS237 2104 BGC0001830 100852
# CNS237 2104 BGC0001830 101071
# CNB440 2688 BGC0000241 77475
# CNB440 2688 BGC0000241 84491

# %%
print('Number of verified link objects: {}'.format(len(established_link_objects)))
# Out:
# Number of verified link objects: 39

# %%
# Load MIBiG structural information

# %%
bgc_structures = {}
with open(mibig_molecular_structures) as f:
    r = csv.reader(f)
    for line in r:
        bgc_id, compound_name, smiles, database_ids = line
        if not bgc_id.startswith('BGC'):
            continue
        if bgc_id in bgc_structures:
            bgc_structures[bgc_id].append(smiles)
        else:
            bgc_structures[bgc_id] = [smiles]

# %%
# Assign SMILES structures to BGCs

# %%
scores_thresh = 10000
bgc_smiles = []
bgc_smiles_index = []
bgc_smiles_scores = []

bgc_smiles_lookup = {}

#debug with only members of known links
#bgc_list = [x[0] for x in established_link_objects]
bgc_list = npl.bgcs
for bgc_idx, bgc in enumerate(bgc_list):
    current_bgc_smiles = set([])
    if bgc in kkb_bgc_hits:
        kkb_bgc = kkb_bgc_hits[bgc][0][0]
        smiles_list = bgc_structures[kkb_bgc]
        for smiles in smiles_list:
            if smiles != '':
                current_bgc_smiles.add(smiles)
                        
    bgc_smiles_lookup[bgc] = current_bgc_smiles
                
    for smiles in current_bgc_smiles:
        bgc_smiles.append(smiles)
        bgc_smiles_index.append(bgc_idx)

# %%
print('total bgc with associated structure: {}'.format(len(set(bgc_smiles_index))))
print('total bgcs: {}'.format(len(npl.bgcs)))
print('total spectra: {}'.format(len(npl.spectra)))
# Out:
# total bgc with associated structure: 2242
# total bgcs: 3316
# total spectra: 6246

# %%
cnt = 0
for g in npl.gcfs:
    for b in g.bgcs:
        bgc_idx = bgc_list.index(b)
        if b in bgc_smiles_lookup and len(bgc_smiles_lookup[b]) != 0:
            cnt += 1
            break
print('strains', len(npl.strains))
print('bgcs', len(npl.bgcs))
print('bgcs struct', len(set(bgc_smiles_index)))
print('gcfs', len(npl.gcfs))
print('gcfs struct', cnt)
print('spectra', len(npl.spectra))
print('molfams', len(npl.molfams))
# Out:
# strains 118
# bgcs 3316
# bgcs struct 2242
# gcfs 454
# gcfs struct 323
# spectra 6246
# molfams 3094

# %%
# Define the reverse lookup table (SMILES -> BGC)

# %%
reverse_smiles_lookup = {}
for smiles, bgc_idx in zip(bgc_smiles, bgc_smiles_index):
    if smiles not in reverse_smiles_lookup:
        reverse_smiles_lookup[smiles] = []
    reverse_smiles_lookup[smiles].append(bgc_idx)

# %%
smiles_list = list(reverse_smiles_lookup.keys())

# %%
# Initialise IOKR

# %%
from nplinker.scoring.iokr import nplinker_iokr

# %%
iokr_server = nplinker_iokr.get_iokr_server()
# Out:
# 16:09:00 [DEBUG] nplinker_iokr.py:193, Init IOKR data server
# 16:09:00 [DEBUG] iokrdata.py:202, IOKRDataServer __init__
# 16:09:00 [DEBUG] iokrdata.py:38, GNPS __init__
# 16:09:00 [DEBUG] iokrdata.py:210, No kernel specified. Please initialise manually.
# 16:09:00 [DEBUG] nplinker_iokr.py:198, Init kernel values
# 16:09:00 [DEBUG] nplinker_iokr.py:203, Load MS files
# 16:09:00 [DEBUG] iokrdata.py:226, IOKRDataServer load_ms_files
# 16:09:00 [DEBUG] iokrdata.py:228, Loading cached MS data
# 16:09:01 [DEBUG] iokrdata.py:232, Done in 0.483827s
# 16:09:01 [DEBUG] nplinker_iokr.py:226, Configure kernel
# 16:09:01 [DEBUG] nplinker_iokr.py:231, Set fingerprint
# 16:09:01 [DEBUG] iokrdata.py:327, IOKRDataServer set_fingerprint
# 16:09:01 [DEBUG] iokrdata.py:335, fpfile is "/home/grimur/git/nplinker/nplinker/prototype/nplinker/scoring/iokr/data/fp_None_gnps.bin.npy"
# 16:09:01 [DEBUG] iokrdata.py:337, Loading GNPS fingerprints from file
# 16:09:01 [DEBUG] iokrdata.py:69, GNPS set_fingerprint_from_file
# 16:09:01 [DEBUG] nplinker_iokr.py:237, fit()
# 16:09:04 [DEBUG] iokrdata.py:51, GNPS get_fingerprints
# 16:09:04 [DEBUG] nplinker_iokr.py:243, get_iokr_server complete!

# %%
# IOKR requires slightly different type of MS spectrum object

# %%
from nplinker.scoring.iokr.spectrum import MSSpectrum

# %%
# Debug with only members of known links
# spectra_list = [x[1] for x in established_link_objects]
spectra_list = npl.spectra
spl = [MSSpectrum(spec=x) for x in spectra_list]

# %%
# Run IOKR on the list of spectra, and the list of SMILES that are assigned to any BGC

# %%
rank = iokr_server.score_smiles(spl, smiles_list)
# Out:
# 14:06:39 [DEBUG] nplinker_iokr.py:39, cache miss
# 14:06:39 [DEBUG] nplinker_iokr.py:40, Calculate fingerprints for candidate set
# 14:06:39 [DEBUG] nplinker_iokr.py:44, done 0/273
# 14:06:39 [DEBUG] nplinker_iokr.py:44, done 1/273
# 14:06:40 [DEBUG] nplinker_iokr.py:44, done 2/273
# 14:06:40 [DEBUG] nplinker_iokr.py:44, done 3/273
# 14:06:41 [DEBUG] nplinker_iokr.py:44, done 4/273
# 14:06:41 [DEBUG] nplinker_iokr.py:44, done 5/273
# 14:06:42 [DEBUG] nplinker_iokr.py:44, done 6/273
# 14:06:42 [DEBUG] nplinker_iokr.py:44, done 7/273
# 14:06:42 [DEBUG] nplinker_iokr.py:44, done 8/273
# 14:06:43 [DEBUG] nplinker_iokr.py:44, done 9/273
# 14:06:43 [DEBUG] nplinker_iokr.py:44, done 10/273
# 14:06:44 [DEBUG] nplinker_iokr.py:44, done 11/273
# 14:06:44 [DEBUG] nplinker_iokr.py:44, done 12/273
# 14:06:44 [DEBUG] nplinker_iokr.py:44, done 13/273
# 14:06:45 [DEBUG] nplinker_iokr.py:44, done 14/273
# 14:06:45 [DEBUG] nplinker_iokr.py:44, done 15/273
# 14:06:45 [DEBUG] nplinker_iokr.py:44, done 16/273
# 14:06:46 [DEBUG] nplinker_iokr.py:44, done 17/273
# 14:06:46 [DEBUG] nplinker_iokr.py:44, done 18/273
# 14:06:46 [DEBUG] nplinker_iokr.py:44, done 19/273
# 14:06:47 [DEBUG] nplinker_iokr.py:44, done 20/273
# 14:06:47 [DEBUG] nplinker_iokr.py:44, done 21/273
# 14:06:47 [DEBUG] nplinker_iokr.py:44, done 22/273
# 14:06:48 [DEBUG] nplinker_iokr.py:44, done 23/273
# 14:06:48 [DEBUG] nplinker_iokr.py:44, done 24/273
# 14:06:48 [DEBUG] nplinker_iokr.py:44, done 25/273
# 14:06:49 [DEBUG] nplinker_iokr.py:44, done 26/273
# 14:06:49 [DEBUG] nplinker_iokr.py:44, done 27/273
# 14:06:49 [DEBUG] nplinker_iokr.py:44, done 28/273
# 14:06:50 [DEBUG] nplinker_iokr.py:44, done 29/273
# 14:06:50 [DEBUG] nplinker_iokr.py:44, done 30/273
# 14:06:50 [DEBUG] nplinker_iokr.py:44, done 31/273
# 14:06:51 [DEBUG] nplinker_iokr.py:44, done 32/273
# 14:06:51 [DEBUG] nplinker_iokr.py:44, done 33/273
# 14:06:51 [DEBUG] nplinker_iokr.py:44, done 34/273
# 14:06:52 [DEBUG] nplinker_iokr.py:44, done 35/273
# 14:06:52 [DEBUG] nplinker_iokr.py:44, done 36/273
# 14:06:53 [DEBUG] nplinker_iokr.py:44, done 37/273
# 14:06:53 [DEBUG] nplinker_iokr.py:44, done 38/273
# 14:06:54 [DEBUG] nplinker_iokr.py:44, done 39/273
# 14:06:54 [DEBUG] nplinker_iokr.py:44, done 40/273
# 14:06:54 [DEBUG] nplinker_iokr.py:44, done 41/273
# 14:06:55 [DEBUG] nplinker_iokr.py:44, done 42/273
# 14:06:55 [DEBUG] nplinker_iokr.py:44, done 43/273
# 14:06:55 [DEBUG] nplinker_iokr.py:44, done 44/273
# 14:06:56 [DEBUG] nplinker_iokr.py:44, done 45/273
# 14:06:56 [DEBUG] nplinker_iokr.py:44, done 46/273
# 14:06:56 [DEBUG] nplinker_iokr.py:44, done 47/273
# 14:06:57 [DEBUG] nplinker_iokr.py:44, done 48/273
# 14:06:57 [DEBUG] nplinker_iokr.py:44, done 49/273
# 14:06:58 [DEBUG] nplinker_iokr.py:44, done 50/273
# 14:06:58 [DEBUG] nplinker_iokr.py:44, done 51/273
# 14:06:58 [DEBUG] nplinker_iokr.py:44, done 52/273
# 14:06:59 [DEBUG] nplinker_iokr.py:44, done 53/273
# 14:06:59 [DEBUG] nplinker_iokr.py:44, done 54/273
# 14:07:00 [DEBUG] nplinker_iokr.py:44, done 55/273
# 14:07:00 [DEBUG] nplinker_iokr.py:44, done 56/273
# 14:07:00 [DEBUG] nplinker_iokr.py:44, done 57/273
# 14:07:01 [DEBUG] nplinker_iokr.py:44, done 58/273
# 14:07:01 [DEBUG] nplinker_iokr.py:44, done 59/273
# 14:07:01 [DEBUG] nplinker_iokr.py:44, done 60/273
# 14:07:02 [DEBUG] nplinker_iokr.py:44, done 61/273
# 14:07:02 [DEBUG] nplinker_iokr.py:44, done 62/273
# 14:07:03 [DEBUG] nplinker_iokr.py:44, done 63/273
# 14:07:03 [DEBUG] nplinker_iokr.py:44, done 64/273
# 14:07:04 [DEBUG] nplinker_iokr.py:44, done 65/273
# 14:07:04 [DEBUG] nplinker_iokr.py:44, done 66/273
# 14:07:05 [DEBUG] nplinker_iokr.py:44, done 67/273
# 14:07:05 [DEBUG] nplinker_iokr.py:44, done 68/273
# 14:07:06 [DEBUG] nplinker_iokr.py:44, done 69/273
# 14:07:06 [DEBUG] nplinker_iokr.py:44, done 70/273
# 14:07:22 [DEBUG] nplinker_iokr.py:44, done 116/273
# 14:07:23 [DEBUG] nplinker_iokr.py:44, done 117/273
# 14:07:23 [DEBUG] nplinker_iokr.py:44, done 118/273
# 14:07:24 [DEBUG] nplinker_iokr.py:44, done 119/273
# 14:07:24 [DEBUG] nplinker_iokr.py:44, done 120/273
# 14:07:24 [DEBUG] nplinker_iokr.py:44, done 121/273
# 14:07:25 [DEBUG] nplinker_iokr.py:44, done 122/273
# 14:07:25 [DEBUG] nplinker_iokr.py:44, done 123/273
# 14:07:25 [DEBUG] nplinker_iokr.py:44, done 124/273
# 14:07:26 [DEBUG] nplinker_iokr.py:44, done 125/273
# 14:07:26 [DEBUG] nplinker_iokr.py:44, done 126/273
# 14:07:26 [DEBUG] nplinker_iokr.py:44, done 127/273
# 14:07:26 [DEBUG] nplinker_iokr.py:44, done 128/273
# 14:07:27 [DEBUG] nplinker_iokr.py:44, done 129/273
# 14:07:27 [DEBUG] nplinker_iokr.py:44, done 130/273
# 14:07:27 [DEBUG] nplinker_iokr.py:44, done 131/273
# 14:07:28 [DEBUG] nplinker_iokr.py:44, done 132/273
# 14:07:28 [DEBUG] nplinker_iokr.py:44, done 133/273
# 14:07:28 [DEBUG] nplinker_iokr.py:44, done 134/273
# 14:07:29 [DEBUG] nplinker_iokr.py:44, done 135/273
# 14:07:29 [DEBUG] nplinker_iokr.py:44, done 136/273
# 14:07:30 [DEBUG] nplinker_iokr.py:44, done 137/273
# 14:07:30 [DEBUG] nplinker_iokr.py:44, done 138/273
# 14:07:30 [DEBUG] nplinker_iokr.py:44, done 139/273
# 14:07:31 [DEBUG] nplinker_iokr.py:44, done 140/273
# 14:07:31 [DEBUG] nplinker_iokr.py:44, done 141/273
# 14:07:32 [DEBUG] nplinker_iokr.py:44, done 142/273
# 14:07:32 [DEBUG] nplinker_iokr.py:44, done 143/273
# 14:07:32 [DEBUG] nplinker_iokr.py:44, done 144/273
# 14:07:32 [DEBUG] nplinker_iokr.py:44, done 145/273
# 14:07:33 [DEBUG] nplinker_iokr.py:44, done 146/273
# 14:07:33 [DEBUG] nplinker_iokr.py:44, done 147/273
# 14:07:33 [DEBUG] nplinker_iokr.py:44, done 148/273
# 14:07:34 [DEBUG] nplinker_iokr.py:44, done 149/273
# 14:07:34 [DEBUG] nplinker_iokr.py:44, done 150/273
# 14:07:34 [DEBUG] nplinker_iokr.py:44, done 151/273
# 14:07:35 [DEBUG] nplinker_iokr.py:44, done 152/273
# 14:07:35 [DEBUG] nplinker_iokr.py:44, done 153/273
# 14:07:36 [DEBUG] nplinker_iokr.py:44, done 154/273
# 14:07:36 [DEBUG] nplinker_iokr.py:44, done 155/273
# 14:07:36 [DEBUG] nplinker_iokr.py:44, done 156/273
# 14:07:37 [DEBUG] nplinker_iokr.py:44, done 157/273
# 14:07:37 [DEBUG] nplinker_iokr.py:44, done 158/273
# 14:07:37 [DEBUG] nplinker_iokr.py:44, done 159/273
# 14:07:38 [DEBUG] nplinker_iokr.py:44, done 160/273
# 14:07:38 [DEBUG] nplinker_iokr.py:44, done 161/273
[DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:53 [DEBUG] nplinker_iokr.py:64, done (0.9843385219573975)
# 14:10:53 [DEBUG] nplinker_iokr.py:65, project
# 14:10:53 [DEBUG] nplinker_iokr.py:69, done (0.001434326171875)
# 14:10:53 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:53 [DEBUG] nplinker_iokr.py:58, Rank spectrum 13 (13/6246)
# 14:10:53 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:54 [DEBUG] nplinker_iokr.py:64, done (0.9744892120361328)
# 14:10:54 [DEBUG] nplinker_iokr.py:65, project
# 14:10:54 [DEBUG] nplinker_iokr.py:69, done (0.0013957023620605469)
# 14:10:54 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:54 [DEBUG] nplinker_iokr.py:58, Rank spectrum 14 (14/6246)
# 14:10:54 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:55 [DEBUG] nplinker_iokr.py:64, done (0.9795718193054199)
# 14:10:55 [DEBUG] nplinker_iokr.py:65, project
# 14:10:55 [DEBUG] nplinker_iokr.py:69, done (0.0014357566833496094)
# 14:10:55 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:55 [DEBUG] nplinker_iokr.py:58, Rank spectrum 15 (15/6246)
# 14:10:55 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:56 [DEBUG] nplinker_iokr.py:64, done (0.9824538230895996)
# 14:10:56 [DEBUG] nplinker_iokr.py:65, project
# 14:10:56 [DEBUG] nplinker_iokr.py:69, done (0.0014607906341552734)
# 14:10:56 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:56 [DEBUG] nplinker_iokr.py:58, Rank spectrum 16 (16/6246)
# 14:10:56 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:57 [DEBUG] nplinker_iokr.py:64, done (0.9733920097351074)
# 14:10:57 [DEBUG] nplinker_iokr.py:65, project
# 14:10:57 [DEBUG] nplinker_iokr.py:69, done (0.0014672279357910156)
# 14:10:57 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:57 [DEBUG] nplinker_iokr.py:58, Rank spectrum 17 (17/6246)
# 14:10:57 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:58 [DEBUG] nplinker_iokr.py:64, done (0.9791088104248047)
# 14:10:58 [DEBUG] nplinker_iokr.py:65, project
# 14:10:58 [DEBUG] nplinker_iokr.py:69, done (0.0013670921325683594)
# 14:10:58 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:58 [DEBUG] nplinker_iokr.py:58, Rank spectrum 18 (18/6246)
# 14:10:58 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:10:59 [DEBUG] nplinker_iokr.py:64, done (0.9761638641357422)
# 14:10:59 [DEBUG] nplinker_iokr.py:65, project
# 14:10:59 [DEBUG] nplinker_iokr.py:69, done (0.0015077590942382812)
# 14:10:59 [DEBUG] nplinker_iokr.py:71, save distances
# 14:10:59 [DEBUG] nplinker_iokr.py:58, Rank spectrum 19 (19/6246)
# 14:10:59 [DEBUG] nplinker_iokr.py:60, kernel vector
# 14:11:00 [DEBUG] nplinker_iokr.py:64, done (0.9781391620635986)
# 14:11:00 [DEBUG] nplinker_iokr.py:65, project
# 14:11:00 [DEBUG] nplinker_iokr.py:69, done (0.0014986991882324219)
# 14:11:00 [DEBUG] nplinker_iokr.py:71, save distances
# 14:11
[DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:51 [DEBUG] nplinker_iokr.py:64, done (1.0144271850585938)
# 15:54:51 [DEBUG] nplinker_iokr.py:65, project
# 15:54:51 [DEBUG] nplinker_iokr.py:69, done (0.0016582012176513672)
# 15:54:51 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:51 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6239 (6239/6246)
# 15:54:51 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:52 [DEBUG] nplinker_iokr.py:64, done (1.06345534324646)
# 15:54:52 [DEBUG] nplinker_iokr.py:65, project
# 15:54:52 [DEBUG] nplinker_iokr.py:69, done (0.001522064208984375)
# 15:54:52 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:52 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6240 (6240/6246)
# 15:54:52 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:53 [DEBUG] nplinker_iokr.py:64, done (1.0314710140228271)
# 15:54:53 [DEBUG] nplinker_iokr.py:65, project
# 15:54:53 [DEBUG] nplinker_iokr.py:69, done (0.001628875732421875)
# 15:54:53 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:53 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6241 (6241/6246)
# 15:54:53 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:54 [DEBUG] nplinker_iokr.py:64, done (1.0278489589691162)
# 15:54:54 [DEBUG] nplinker_iokr.py:65, project
# 15:54:54 [DEBUG] nplinker_iokr.py:69, done (0.001573801040649414)
# 15:54:54 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:54 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6242 (6242/6246)
# 15:54:54 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:55 [DEBUG] nplinker_iokr.py:64, done (1.0197389125823975)
# 15:54:55 [DEBUG] nplinker_iokr.py:65, project
# 15:54:55 [DEBUG] nplinker_iokr.py:69, done (0.0014286041259765625)
# 15:54:55 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:55 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6243 (6243/6246)
# 15:54:55 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:56 [DEBUG] nplinker_iokr.py:64, done (1.0146496295928955)
# 15:54:56 [DEBUG] nplinker_iokr.py:65, project
# 15:54:56 [DEBUG] nplinker_iokr.py:69, done (0.0014920234680175781)
# 15:54:56 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:56 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6244 (6244/6246)
# 15:54:56 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:57 [DEBUG] nplinker_iokr.py:64, done (1.0389111042022705)
# 15:54:57 [DEBUG] nplinker_iokr.py:65, project
# 15:54:57 [DEBUG] nplinker_iokr.py:69, done (0.0016586780548095703)
# 15:54:57 [DEBUG] nplinker_iokr.py:71, save distances
# 15:54:57 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6245 (6245/6246)
# 15:54:57 [DEBUG] nplinker_iokr.py:60, kernel vector
# 15:54:58 [DEBUG] nplinker_iokr.py:64, done (1.0071280002593994)
# 15:54:58 [DEBUG] nplinker_iokr.py:65, project
# 15:54:58 [DEBUG] nplinker_iokr.py:69, done (0.0014300346374511719)
# 15:54:58 [DEBUG] nplinker_iokr.py:71, save distances

# %%
# cache results

# %%
import pickle
with open('saved_data_crusemann.bin', 'rb') as f:
    rank = pickle.load(f)

# %%
import pickle
with open('saved_data_crusemann.bin', 'wb') as f:
    pickle.dump(rank, f)

# %%
iokr_scores = rank

# %%
# Translate the BGC-MS IOKR score into GCF-MF score

# %%
def get_iokr_score(mf, gcf):
    potential_scores = []
    for spectrum in mf.spectra:
        spectrum_idx = npl.spectra.index(spectrum)
        for bgc in gcf.bgcs:
            bgc_smiles_list = bgc_smiles_lookup[bgc]
            for smiles in bgc_smiles_list:
                smiles_index = smiles_list.index(smiles)
                spectrum_smiles_score = iokr_scores[spectrum_idx, smiles_index]
                potential_scores.append(spectrum_smiles_score)
    if len(potential_scores) == 0:
        return -100
    else:
        return max(potential_scores)

# %%
# Find the data set objects corresponding to the established links

# %%
verified_bgc_mf_links = []
verified_bgc_mf_links_labels = []
for bgc, kkb_hits in kkb_bgc_hits.items():
    for strain_id, mibig_id, molfam_id in established_links:
        if strain_id == bgc.strain.id or strain_id in bgc.strain.aliases:
            if mibig_id in [x[0] for x in kkb_hits if x[1] > 10000]:
                for molecular_family in npl.molfams:
                    if molecular_family.family_id == molfam_id:
                        verified_bgc_mf_links.append((bgc, molecular_family))
                        verified_bgc_mf_links_labels.append(mibig_id)

# %%
for a, b in verified_bgc_mf_links:
    print(a.id, a.strain, b.id)
# Out:
# 394 Strain(CNS205) [5 aliases] 1726
# 394 Strain(CNS205) [5 aliases] 1785
# 711 Strain(CNS205) [5 aliases] 1726
# 711 Strain(CNS205) [5 aliases] 1785
# 739 Strain(CNS205) [5 aliases] 3039
# 990 Strain(CNT005) [4 aliases] 3079
# 1642 Strain(CNS205) [5 aliases] 832
# 2104 Strain(CNS237) [4 aliases] 1401
# 2688 Strain(CNB440) [5 aliases] 1988

# %%
scores_from_bgc_idlist = []

# scores_from_bgc has order (IOKR, std.corr., raw corr)

for (valid_bgc, valid_mf), mibig_id in zip(verified_bgc_mf_links, verified_bgc_mf_links_labels):
    #print(valid_bgc.id, gcf.bgcs)
    for gcf in npl.gcfs:
        print(gcf.product_type)
        if valid_bgc.id in [x.id for x in gcf.bgcs]:
            scores_from_bgc_idlist.append((gcf, valid_bgc, mibig_id, valid_mf))
# Out:
# NRPS
# Others
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# Others
# PKSI
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# Others
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# Others
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# RiPPs
# Others
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Saccharides
# Saccharides
# Saccharides
# Others
# Terpene
# Terpene
# Terpene
# Others
# Terpene
# Others
# Others
# Others
# Others
# Others
# Terpene
# Terpene
# Others
# Others
# Terpene
# NRPS
# Others
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# Others
# PKSI
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# Others
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# Others
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# RiPPs
# Others
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Saccharides
# Saccharides
# Saccharides
# Others
# Terpene
# Terpene
# Terpene
# Others
# Terpene
# Others
# Others
# Others
# Others
# Others
# Terpene
# Terpene
# Others
# Others
# Terpene
# NRPS
# Others
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# Others
# PKSI
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# Others
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# Others
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKSother
# PKSother
# PKSother
# PKSother
# PKS-NRP_Hybrids
# PKSother
# PKS-NRP_Hybrids
# RiPPs
# Others
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Saccharides
# Saccharides
# Saccharides
# Others
# Terpene
# Terpene
# Terpene
# Others
# Terpene
# Others
# Others
# Others
# Others
# Others
# Terpene
# Terpene
# Others
# Others
# Terpene
# NRPS
# Others
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# Others
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# PKS-NRP_Hybrids
# Others
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# NRPS
# PKS-NRP_Hybrids
# NRPS
# Others
# PKS-NRP_Hybrids
# NRPS
# PKS-NRP_Hybrids
# Others
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# NRPS
# NRPS
# Others
# NRPS
# NRPS
# NRPS
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# Others
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# PKSI
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# Others
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# RiPPs
# Saccharides
# Saccharides
# Saccharides
# Others
# Terpene
# Terpene
# Terpene
# Others
# Terpene
# Others
# Others
# Others
# Others
# Others
# Terpene
# Terpene
# Others
# Others
# Terpene

# %%
# Assemble a list of IOKR and correlation scores for all potential links, and validated links

# %%
from nplinker.scoring import misc
strains = npl.strains

# %%
all_score_pairs = []
verified_score_pairs = []

for i, gcf in enumerate(npl.gcfs):
    print("{} / {}".format(i, len(npl.gcfs)))
    
    for mf in npl.molfams:
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
        iokr_score = get_iokr_score(mf, gcf)
        
        all_score_pairs.append((metcalf_score, iokr_score))
        for link_bgc, link_mf in verified_bgc_mf_links:
            if link_bgc in gcf.bgcs and link_mf == mf:
                print('add verified')
                verified_score_pairs.append((metcalf_score, iokr_score))
# Out:
# 0 / 454
# 1 / 454
# 2 / 454
# 3 / 454
# 4 / 454
# 5 / 454
# 6 / 454
# 7 / 454
# 8 / 454
# 9 / 454
# 10 / 454
# 11 / 454
# 12 / 454
# 13 / 454
# 14 / 454
# 15 / 454
# 16 / 454
# 17 / 454
# 18 / 454
# 19 / 454
# 20 / 454
# 21 / 454
# 22 / 454
# 23 / 454
# 24 / 454
# 25 / 454
# 26 / 454
# 27 / 454
# 28 / 454
# 29 / 454
# 30 / 454
# 31 / 454
# 32 / 454
# 33 / 454
# 34 / 454
# 35 / 454
# 36 / 454
# 37 / 454
# 38 / 454
# 39 / 454
# 40 / 454
# 41 / 454
# 42 / 454
# 43 / 454
# 44 / 454
# 45 / 454
# 46 / 454
# 47 / 454
# 48 / 454
# 49 / 454
# 50 / 454
# 51 / 454
# 52 / 454
# 53 / 454
# 54 / 454
# 55 / 454
# 56 / 454
# 57 / 454
# 58 / 454
# 59 / 454
# 60 / 454
# 61 / 454
# 62 / 454
# 63 / 454
# 64 / 454
# 65 / 454
# 66 / 454
# 67 / 454
# 68 / 454
# 69 / 454
# 70 / 454
# 71 / 454
# 72 / 454
# 73 / 454
# 74 / 454
# 75 / 454
# 76 / 454
# 77 / 454
# 78 / 454
# 79 / 454
# 80 / 454
# 81 / 454
# 82 / 454
# 83 / 454
# 84 / 454
# 85 / 454
# 86 / 454
# 87 / 454
# 88 / 454
# 89 / 454
# 90 / 454
# 91 / 454
# 92 / 454
# 93 / 454
# 94 / 454
# 95 / 454
# 96 / 454
# 97 / 454
# 98 / 454
# 99 / 454
# 100 / 454
# 101 / 454
# 102 / 454
# 103 / 454
# 104 / 454
# 105 / 454
# 106 / 454
# 107 / 454
# 108 / 454
# 109 / 454
# 110 / 454
# 111 / 454
# 112 / 454
# 113 / 454
# 114 / 454
# 115 / 454
# 116 / 454
# 117 / 454
# 118 / 454
# 119 / 454
# 120 / 454
# 121 / 454
# 122 / 454
# 123 / 454
# 124 / 454
# 125 / 454
# 126 / 454
# 127 / 454
# 128 / 454
# 129 / 454
# 130 / 454
# 131 / 454
# 132 / 454
# 133 / 454
# 134 / 454
# 423 / 454
# 424 / 454
# 425 / 454
# 426 / 454
# 427 / 454
# 428 / 454
# 429 / 454
# 430 / 454
# 431 / 454
# 432 / 454
# 433 / 454
# 434 / 454
# 435 / 454
# 436 / 454
# 437 / 454
# 438 / 454
# 439 / 454
# 440 / 454
# 441 / 454
# 442 / 454
# 443 / 454
# 444 / 454
# 445 / 454
# 446 / 454
# 447 / 454
# 448 / 454
# 449 / 454
# 450 / 454
# 451 / 454
# 452 / 454
# 453 / 454

# %%
# Write links above 99th percentile for both scores into file (supplementary info)

# %%
metcalf_limit_99 = numpy.percentile([x[0] for x in all_score_pairs], 99)
iokr_limit_99 = numpy.percentile([x[1] for x in all_score_pairs], 99)

with open('links_crusemann_99.csv', 'w') as f:
    w = csv.writer(f)
    for i, gcf in enumerate(npl.gcfs):
        print('{}/{}'.format(i, len(npl.gcfs)))
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
        raw_metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=False)

        for mf in npl.molfams:
            try:
                molfam_id = mf.family_id
            except AttributeError:
                molfam_id = -1

            for bgc in gcf.bgcs:
                if (bgc, mf) in verified_bgc_mf_links:
                    verified = 1
                else:
                    verified = 0

                if bgc not in kkb_bgc_hits:
                    continue
                    
                mibig_hits = ';'.join('{}:{}'.format(*x) for x in kkb_bgc_hits[bgc])

                for spectrum in mf.spectra:
                    spectrum_idx = npl.spectra.index(spectrum)

                    bgc_smiles_list = bgc_smiles_lookup[bgc]
                    for smiles in bgc_smiles_list:
                        smiles_index = smiles_list.index(smiles)
                        spectrum_smiles_score = iokr_scores[spectrum_idx, smiles_index]

                        data = [
                            bgc.name,
                            gcf.gcf_id,
                            spectrum.spectrum_id,
                            molfam_id,
                            smiles,
                            spectrum_smiles_score,
                            metcalf_score,
                            raw_metcalf_score,
                            verified,
                            mibig_hits
                        ]
                        
                        if (spectrum_smiles_score > iokr_limit_99 or metcalf_score > metcalf_limit_99) or verified == 1:
                            w.writerow(data)
# Out:
# 0/454
# 1/454
# 2/454
# 3/454
# 4/454
# 5/454
# 6/454
# 7/454
# 8/454
# 9/454
# 10/454
# 11/454
# 12/454
# 13/454
# 14/454
# 15/454
# 16/454
# 17/454
# 18/454
# 19/454
# 20/454
# 21/454
# 22/454
# 23/454
# 24/454
# 25/454
# 26/454
# 27/454
# 28/454
# 29/454
# 30/454
# 31/454
# 32/454
# 33/454
# 34/454
# 35/454
# 36/454
# 37/454
# 38/454
# 39/454
# 40/454
# 41/454
# 42/454
# 43/454
# 44/454
# 45/454
# 46/454
# 47/454
# 48/454
# 49/454
# 50/454
# 51/454
# 52/454
# 53/454
# 54/454
# 55/454
# 56/454
# 57/454
# 58/454
# 59/454
# 60/454
# 61/454
# 62/454
# 63/454
# 64/454
# 65/454
# 66/454
# 67/454
# 68/454
# 69/454
# 70/454
# 71/454
# 72/454
# 73/454
# 74/454
# 75/454
# 76/454
# 77/454
# 78/454
# 79/454
# 80/454
# 81/454
# 82/454
# 83/454
# 84/454
# 85/454
# 86/454
# 344/454
# 345/454
# 346/454
# 347/454
# 348/454
# 349/454
# 350/454
# 351/454
# 352/454
# 353/454
# 354/454
# 355/454
# 356/454
# 357/454
# 358/454
# 359/454
# 360/454
# 361/454
# 362/454
# 363/454
# 364/454
# 365/454
# 366/454
# 367/454
# 368/454
# 369/454
# 370/454
# 371/454
# 372/454
# 373/454
# 374/454
# 375/454
# 376/454
# 377/454
# 378/454
# 379/454
# 380/454
# 381/454
# 382/454
# 383/454
# 384/454
# 385/454
# 386/454
# 387/454
# 388/454
# 389/454
# 390/454
# 391/454
# 392/454
# 393/454
# 394/454
# 395/454
# 396/454
# 397/454
# 398/454
# 399/454
# 400/454
# 401/454
# 402/454
# 403/454
# 404/454
# 405/454
# 406/454
# 407/454
# 408/454
# 409/454
# 410/454
# 411/454
# 412/454
# 413/454
# 414/454
# 415/454
# 416/454
# 417/454
# 418/454
# 419/454
# 420/454
# 421/454
# 422/454
# 423/454
# 424/454
# 425/454
# 426/454
# 427/454
# 428/454
# 429/454
# 430/454
# 431/454
# 432/454
# 433/454
# 434/454
# 435/454
# 436/454
# 437/454
# 438/454
# 439/454
# 440/454
# 441/454
# 442/454
# 443/454
# 444/454
# 445/454
# 446/454
# 447/454
# 448/454
# 449/454
# 450/454
# 451/454
# 452/454
# 453/454

# %%
# Begin analysis + figure part

# %%
import scipy

# %%
iokr_scores_all = [x[1] for x in all_score_pairs if x[1] != -100]
iokr_scores_valid = [x[1] for x in verified_score_pairs if x[1] != -100]
print('Mean IOKR all: {}'.format(numpy.mean(iokr_scores_all)))
print('Mean IOKR valid: {}'.format(numpy.mean(iokr_scores_valid)))
print('IOKR difference in means p-value: {}'.format(scipy.stats.ttest_ind(iokr_scores_all, iokr_scores_valid)))
# Out:
# Mean IOKR all: 0.010650065488149058
# Mean IOKR valid: 0.03668041305353406
# IOKR difference in means p-value: Ttest_indResult(statistic=-6.013251322359768, pvalue=1.8190152592103703e-09)

# %%
metcalf_scores_all = [x[0] for x in all_score_pairs if x[1] != -100]
metcalf_scores_valid = [x[0] for x in verified_score_pairs if x[1] != -100]
print('Mean Metcalf all: {}'.format(numpy.mean(metcalf_scores_all)))
print('Mean Metcalf valid: {}'.format(numpy.mean(metcalf_scores_valid)))
print('Metcalf difference in means p-value: {}'.format(scipy.stats.ttest_ind(metcalf_scores_all, metcalf_scores_valid)))
# Out:
# Mean Metcalf all: -0.006852202755015838
# Mean Metcalf valid: 2.9505876831010616
# Metcalf difference in means p-value: Ttest_indResult(statistic=-13.90148114612521, pvalue=6.263233437841528e-44)

# %%
# ratio of verified links, and of verified links scoring above n-th percentile

# %%
test_percentile = 95
iokr_percentile = numpy.percentile(iokr_scores_all, test_percentile)
metcalf_percentile = numpy.percentile(metcalf_scores_all, test_percentile)

total_link_ratio = len(iokr_scores_valid) / len(iokr_scores_all)

iokr_percentile_ratio = len([x for x in iokr_scores_valid if x >= iokr_percentile]) / len([x for x in iokr_scores_all if x >= iokr_percentile])
metcalf_percentile_ratio = len([x for x in metcalf_scores_valid if x >= metcalf_percentile]) / len([x for x in metcalf_scores_all if x >= metcalf_percentile])

both_percentile_ratio = len([x for x in verified_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]) / len([x for x in all_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile])

print('Total ratio: {}'.format(total_link_ratio))
print('IOKR ratio: {}'.format(iokr_percentile_ratio))
print('Metcalf ratio: {}'.format(metcalf_percentile_ratio))
print('Combined ratio: {}'.format(both_percentile_ratio))
# Out:
# Total ratio: 1.5009576109557898e-05
# IOKR ratio: 0.00012007204322593557
# Metcalf ratio: 0.00019910799617712648
# Combined ratio: 0.0015891934843067143

# %%
# Scoring list cache

# %%
import pickle
import numpy
with open('20200402_crusemann_metcalf_iokr_verified.bin', 'rb') as f:
    (iokr_scores_all, 
                 iokr_scores_valid, 
                 metcalf_scores_all, 
                 metcalf_scores_valid, 
                 metcalf_raw_scores_all, 
                 metcalf_raw_scores_valid,
                 all_score_pairs,
                 verified_score_pairs) = pickle.load(f)

# %%
metcalf_raw_all_scores = metcalf_raw_scores_all
metcalf_raw_verified_scores = metcalf_raw_scores_valid

# %%
# ratio of verified links, and of verified links scoring above n-th percentile

# %%
test_percentile = 90
iokr_percentile = numpy.percentile(iokr_scores_all, test_percentile)
metcalf_percentile = numpy.percentile(metcalf_scores_all, test_percentile)

total_link_ratio = len(iokr_scores_valid) / len(iokr_scores_all)

iokr_percentile_ratio = len([x for x in iokr_scores_valid if x >= iokr_percentile]) / len([x for x in iokr_scores_all if x >= iokr_percentile])
metcalf_percentile_ratio = len([x for x in metcalf_scores_valid if x >= metcalf_percentile]) / len([x for x in metcalf_scores_all if x >= metcalf_percentile])

both_percentile_ratio = len([x for x in verified_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]) / len([x for x in all_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile])

print('Total ratio: {}'.format(total_link_ratio))
print('IOKR ratio: {}'.format(iokr_percentile_ratio))
print('Metcalf ratio: {}'.format(metcalf_percentile_ratio))
print('Combined ratio: {}'.format(both_percentile_ratio))
# Out:
# Total ratio: 1.5009576109557898e-05
# IOKR ratio: 6.003782382901228e-05
# Metcalf ratio: 0.00012936095687304716
# Combined ratio: 0.0004614248800295312

# %%
# Count of all links and verified links, scoring above n-th percentile

# %%
test_percentile = 95
iokr_percentile = numpy.percentile(iokr_scores_all, test_percentile)
metcalf_percentile = numpy.percentile(metcalf_scores_all, test_percentile)

print('raw valid', len(iokr_scores_valid))
print('raw all', len(iokr_scores_all))
print('iokr valid', len([x for x in iokr_scores_valid if x >= iokr_percentile]))
print('iokr all', len([x for x in iokr_scores_all if x >= iokr_percentile]))
print('metcalf valid', len([x for x in metcalf_scores_valid if x >= metcalf_percentile]))
print('metcalf all', len([x for x in metcalf_scores_all if x >= metcalf_percentile]))
print('both valid', len([x for x in verified_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]))
print('both all', len([x for x in all_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]))
# Out:
# raw valid 15
# raw all 999362
# iokr valid 6
# iokr all 49970
# metcalf valid 10
# metcalf all 50224
# both valid 4
# both all 2517

# %%
test_percentile = 90
iokr_percentile = numpy.percentile(iokr_scores_all, test_percentile)
metcalf_percentile = numpy.percentile(metcalf_scores_all, test_percentile)

print('raw valid', len(iokr_scores_valid))
print('raw all', len(iokr_scores_all))
print('iokr valid', len([x for x in iokr_scores_valid if x >= iokr_percentile]))
print('iokr all', len([x for x in iokr_scores_all if x >= iokr_percentile]))
print('metcalf valid', len([x for x in metcalf_scores_valid if x >= metcalf_percentile]))
print('metcalf all', len([x for x in metcalf_scores_all if x >= metcalf_percentile]))
print('both valid', len([x for x in verified_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]))
print('both all', len([x for x in all_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]))
# Out:
# raw valid 15
# raw all 999362
# iokr valid 6
# iokr all 99937
# metcalf valid 13
# metcalf all 100494
# both valid 5
# both all 10836

# %%
# reimport, b/c I accidentally overwrote the other one...
from matplotlib import pyplot as plt
from matplotlib import gridspec

# %%
# Plots

# %%
fig_size = 9.3
fig = plt.figure(figsize=(fig_size, float(fig_size)/2))


# ax_min = -0.15
ax_min = min(metcalf_raw_all_scores)
# ax_max = 0.35
ax_max = max(metcalf_raw_all_scores)

gs = gridspec.GridSpec(1, 1, hspace=0.05)

ax1 = plt.subplot(gs[0])
#ax2 = plt.subplot(gs[1])


ax1.hist(metcalf_raw_all_scores, bins=50, range=[ax_min, ax_max], alpha=0.5)
ax1.plot(metcalf_raw_verified_scores, [0]*len(metcalf_raw_verified_scores), '|', color='k', markersize=50)

ax1.set_xlim([ax_min, ax_max])
#ax2.set_xlim([ax_min, ax_max])
#ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_ylabel('count')
ax1.set_xlabel('score')

plt.tight_layout()

plt.savefig('20200511_graph_metcalf_raw_crusemann.pdf')
# Out:
# /home/grimur/miniconda2/envs/jupyter-py3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
plot = sns.jointplot([x[0] for x in all_score_pairs if x[1] != -100], [x[1] for x in all_score_pairs if x[1] != -100], alpha=0.1, ratio=2, height=8, marginal_kws={'hist_kws': {'alpha': 0.5}})
plot.ax_joint.plot([x[0] for x in verified_score_pairs if x[1] != -100], [x[1] for x in verified_score_pairs if x[1] != -100], 'ro', color='r')
# bc horizontal, flip x and y axis
plot.ax_marg_y.plot([0]*len(iokr_scores_valid), iokr_scores_valid, '|', color='k', marker=(2, 0, 90), markersize=50)
plot.ax_marg_x.plot(metcalf_scores_valid, [0]*len(metcalf_scores_valid), '|', color='k', markersize=50)


plot.set_axis_labels('Standardised strain correlation score', 'IOKR score', size='large')

filename = '20210204_graph_combined_data_iokr_metcalf'


data = (all_score_pairs, verified_score_pairs)

with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plot.savefig(filename + '.png')#, dpi=1200)

# %%
# Fig. for SI

plot = sns.jointplot([x[0] for x in all_score_pairs if x[1] != -100], [x[1] for x in all_score_pairs if x[1] != -100], alpha=0.1, ratio=2, height=12, marginal_kws={'hist_kws': {'alpha': 0.5}})
plot.ax_joint.plot([x[0] for x in verified_score_pairs if x[1] != -100], [x[1] for x in verified_score_pairs if x[1] != -100], 'ro', color='r')
# bc horizontal, flip x and y axis
plot.ax_marg_y.plot([0]*len(iokr_scores_valid), iokr_scores_valid, '|', color='k', marker=(2, 0, 90), markersize=50)
plot.ax_marg_x.plot(metcalf_scores_valid, [0]*len(metcalf_scores_valid), '|', color='k', markersize=50)


#plot.set_axis_labels('Standardised strain correlation score', 'IOKR score', size='large')
plot.set_axis_labels('Strain correlation score', 'IOKR score')


filename = '20210208_graph_combined_data_iokr_metcalf'


data = (all_score_pairs, verified_score_pairs)

with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plot.savefig(filename + '.png')#, dpi=1200)

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure(figsize=(8, 6))

filename = '20200402_graph_iokr_paired_data_crusemann'

# ax_min = -0.15
ax_min = -0.05
# ax_max = 0.35
ax_max = 0.1

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('IOKR score for established links vs. random')

ax1.hist(iokr_scores_all, bins=50, range=[ax_min, ax_max])

ax2.plot(iokr_scores_valid, [5000]*len(iokr_scores_valid), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

data = (iokr_scores_all, iokr_scores_valid)
with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plt.savefig('20200402_graph_iokr_paired_data_crusemann.png')

# %%
fig = plt.figure(figsize=(8, 6))


# ax_min = -0.15
ax_min = min(metcalf_all_scores)
# ax_max = 0.35
ax_max = max(metcalf_all_scores)

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('Strain correlation score for established links vs. random')

ax1.hist(metcalf_scores_all, bins=50, range=[ax_min, ax_max])

ax2.plot(metcalf_scores_valid, [5000]*len(metcalf_scores_valid), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

plt.savefig('graph_metcalf_paired_data_crusemann.png')

# %%
print("Valid links: {}".format(len(metcalf_scores_valid)))
print("Links > 0: {}".format(len([x for x in metcalf_scores_valid if x > 0])))
# Out:
# Valid links: 15
# Links > 0: 13

# %%
# This is a duplicate!

# %%
metcalf_raw_all_scores = []
metcalf_raw_verified_scores = []

for i, gcf in enumerate(npl.gcfs):
    print("{} / {}".format(i, len(npl.gcfs)))
    
    for mf in npl.molfams:
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=False)
# 362 / 454
# 363 / 454
# 364 / 454
# 365 / 454
# 366 / 454
# 367 / 454
# add verified
# add verified
# 368 / 454
# 369 / 454
# 370 / 454
# 371 / 454
# 372 / 454
# 373 / 454
# 374 / 454
# 375 / 454
# 376 / 454
# 377 / 454
# add verified
# 378 / 454
# 379 / 454
# 380 / 454
# 381 / 454
# 382 / 454
# 383 / 454
# 384 / 454
# 385 / 454
# 386 / 454
# 387 / 454
# 388 / 454
# 389 / 454
# 390 / 454
# 391 / 454
# 392 / 454
# 393 / 454
# 394 / 454
# 395 / 454
# 396 / 454
# 397 / 454
# 398 / 454
# 399 / 454
# 400 / 454
# 401 / 454
# 402 / 454
# 403 / 454
# 404 / 454
# 405 / 454
# 406 / 454
# 407 / 454
# 408 / 454
# 409 / 454
# 410 / 454
# 411 / 454
# 412 / 454
# 413 / 454
# 414 / 454
# 415 / 454
# 416 / 454
# 417 / 454
# 418 / 454
# 419 / 454
# 420 / 454
# 421 / 454
# 422 / 454
# 423 / 454
# 424 / 454
# 425 / 454
# 426 / 454
# 427 / 454
# 428 / 454
# 429 / 454
# 430 / 454
# 431 / 454
# 432 / 454
# 433 / 454
# 434 / 454
# 435 / 454
# 436 / 454
# 437 / 454
# 438 / 454
# 439 / 454
# 440 / 454
# 441 / 454
# 442 / 454
# 443 / 454
# 444 / 454
# 445 / 454
# 446 / 454
# 447 / 454
# 448 / 454
# 449 / 454
# 450 / 454
# 451 / 454
# 452 / 454
# 453 / 454

# %%
fig = plt.figure(figsize=(8, 6))


# ax_min = -0.15
ax_min = min(metcalf_raw_all_scores)
# ax_max = 0.35
ax_max = max(metcalf_raw_all_scores)

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('Raw strain correlation score for established links vs. random')

ax1.hist(metcalf_raw_all_scores, bins=50, range=[ax_min, ax_max])

ax2.plot(metcalf_raw_verified_scores, [5000]*len(metcalf_raw_verified_scores), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

plt.savefig('graph_metcalf_raw_paired_data_crusemann.png')

# %%
metcalf_raw_scores_all = [x for x, y in zip(metcalf_raw_all_scores, all_score_pairs) if y[1] != -100]
metcalf_raw_scores_valid = [x for x, y in zip(metcalf_raw_verified_scores, verified_score_pairs) if y[1] != -100]
print('Mean Metcalf all: {}'.format(numpy.mean(metcalf_raw_scores_all)))
print('Mean Metcalf valid: {}'.format(numpy.mean(metcalf_raw_scores_valid)))
print('Metcalf difference in means p-value: {}'.format(scipy.stats.ttest_ind(metcalf_raw_scores_all, metcalf_raw_scores_valid)))
# Out:
# Mean Metcalf all: 84.19524256475631
# Mean Metcalf valid: 14.0
# Metcalf difference in means p-value: Ttest_indResult(statistic=3.9408053673283527, pvalue=8.121401609179454e-05)

# %%
# cache results...

# %%
with open('20200402_crusemann_metcalf_iokr_verified.bin', 'wb') as f:
    pickle.dump((iokr_scores_all, 
                 iokr_scores_valid, 
                 metcalf_scores_all, 
                 metcalf_scores_valid, 
                 metcalf_raw_scores_all, 
                 metcalf_raw_scores_valid,
                 all_score_pairs,
                 verified_score_pairs), f)

# %%
# Plot standardised vs. raw correlation score

# %%
fig = plt.figure(figsize=(8, 4))

filename = '20200514_raw_vs_standardised_correlation_score_crusemann'

metcalf_raw_all_scores = metcalf_raw_scores_all

# ax_min = -0.15
raw_ax_min = min(metcalf_raw_all_scores)
# ax_max = 0.35
raw_ax_max = max(metcalf_raw_all_scores)

gs = gridspec.GridSpec(2, 2, height_ratios=[20, 2], hspace=0.05)
raw_hist = plt.subplot(gs[0])
raw_ticks = plt.subplot(gs[2])

raw_hist.set_title('Raw', size='large')

raw_hist.hist(metcalf_raw_scores_all, bins=50, range=[raw_ax_min, raw_ax_max])

raw_ticks.plot(metcalf_raw_scores_valid, [5000]*len(metcalf_raw_scores_valid), '|', color='k', markersize=50)
raw_hist.set_xlim([raw_ax_min, raw_ax_max])
raw_ticks.set_xlim([raw_ax_min, raw_ax_max])
raw_hist.set_xticks([])
raw_ticks.set_yticks([])

raw_hist.set_ylabel('count')
raw_ticks.set_xlabel('score')

# raw_hist.yaxis.tick_left()


# ax_min = -0.15
std_ax_min = min(metcalf_scores_all)
# ax_max = 0.35
std_ax_max = max(metcalf_scores_all)


std_hist = plt.subplot(gs[1])
std_ticks = plt.subplot(gs[3])

std_hist.set_title('Standardised', size='large')

std_hist.hist(metcalf_scores_all, bins=50, range=[std_ax_min, std_ax_max])

std_ticks.plot(metcalf_scores_valid, [5000]*len(metcalf_scores_valid), '|', color='k', markersize=50)
std_hist.set_xlim([std_ax_min, std_ax_max])
std_ticks.set_xlim([std_ax_min, std_ax_max])
std_hist.set_xticks([])
std_ticks.set_yticks([])

#ax1.set_yticks([])
#std_hist.yaxis.tick_right()
std_hist.set_yticklabels([])

# ax1.set_ylabel('count')
std_ticks.set_xlabel('score', size='medium')

hist_max = max(std_hist.get_ylim()[1], raw_hist.get_ylim()[1])
std_hist.set_ylim(top=hist_max)
raw_hist.set_ylim(top=hist_max)


plt.tight_layout()

#data = (metcalf_raw_all_scores, metcalf_raw_verified_scores, metcalf_scores_all, metcalf_scores_valid)
#with open(filename + '.bin', 'wb') as f:
#    pickle.dump(data, f)

plt.savefig(filename + '.pdf')
# Out:
# /home/grimur/miniconda2/envs/jupyter-py3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# Scores starting from a given BGC

# %%
scores_from_bgc = []
scores_from_bgc_idlist = []

# scores_from_bgc has order (IOKR, std.corr., raw corr)

for (valid_bgc, valid_mf), mibig_id in zip(verified_bgc_mf_links, verified_bgc_mf_links_labels):
    for gcf in npl.gcfs:
        if valid_bgc.id in [x.id for x in gcf.bgcs]:
            iokr_score_list = []
            metcalf_score_list = []
            raw_metcalf_score_list = []
            for mf in npl.molfams:
                iokr_score = get_iokr_score(mf, gcf)
                iokr_score_list.append(iokr_score)
                raw_metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=False)
                raw_metcalf_score_list.append(raw_metcalf_score)
                metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
                metcalf_score_list.append(metcalf_score)
                if mf == valid_mf:
                    valid_iokr_score = iokr_score
                    valid_metcalf_score = metcalf_score
                    valid_raw_metcalf_score = raw_metcalf_score
            scores_from_bgc.append((
                (iokr_score_list, valid_iokr_score),
                (metcalf_score_list, valid_metcalf_score),
                (raw_metcalf_score_list, valid_raw_metcalf_score)
            ))
                
            scores_from_bgc_idlist.append((gcf, valid_bgc, mibig_id))

# %%
scores_from_bgc_idlist
# Out:
# [(GCF(id=71, class=PKS-NRP_Hybrids, gcf_id=980, strains=26),
#   BGC(id=394, name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=333, class=PKS-NRP_Hybrids, gcf_id=863, strains=16),
#   BGC(id=394, name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=71, class=PKS-NRP_Hybrids, gcf_id=980, strains=26),
#   BGC(id=394, name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=333, class=PKS-NRP_Hybrids, gcf_id=863, strains=16),
#   BGC(id=394, name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=48, class=PKS-NRP_Hybrids, gcf_id=767, strains=10),
#   BGC(id=711, name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=123, class=PKS-NRP_Hybrids, gcf_id=2015, strains=2),
#   BGC(id=711, name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=367, class=PKS-NRP_Hybrids, gcf_id=2512, strains=9),
#   BGC(id=711, name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=48, class=PKS-NRP_Hybrids, gcf_id=767, strains=10),
#   BGC(id=711, name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=123, class=PKS-NRP_Hybrids, gcf_id=2015, strains=2),
#   BGC(id=711, name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=367, class=PKS-NRP_Hybrids, gcf_id=2512, strains=9),
#   BGC(id=711, name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=132, class=Others, gcf_id=2241, strains=2),
#   BGC(id=739, name=GCA_000018265.CP000850.1.region024, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000333'),
#  (GCF(id=161, class=NRPS, gcf_id=2865, strains=1),
#   BGC(id=990, name=GCA_000514895.KI911494.1.region001, strain=Strain(CNT005) [4 aliases]),
#   'BGC0001228'),
#  (GCF(id=232, class=Others, gcf_id=2864, strains=61),
#   BGC(id=1642, name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000827'),
#  (GCF(id=295, class=PKSI, gcf_id=2151, strains=3),
#   BGC(id=2104, name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   'BGC0001830'),
#  (GCF(id=377, class=PKSother, gcf_id=3067, strains=15),
#   BGC(id=2688, name=GCA_000016425.CP000667.1.region006, strain=Strain(CNB440) [5 aliases]),
#   'BGC0000241')]

# %%
# Plot scores for a selection of BGCs

# %%
sample_plot_indices = [9, 11, 14]

#w = 8
w = 9.2
h = (32.0 / 15 * 3) / 9 * 8

filename = '20210204_bgc_scores_crusemann'

fig, axes = plt.subplots(nrows=len(sample_plot_indices), ncols=4, figsize=(w, h))

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col, size='large')

pad = 5

for row_idx, sample_idx in enumerate(sample_plot_indices):
    gcf, bgc, mibig = scores_from_bgc_idlist[sample_idx]
    
    #axes[row_idx, 0].set_ylabel(mibig)
    ax = axes[row_idx, 0]
    n = ax.annotate(mibig, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0), 
                xycoords=ax.yaxis.label, textcoords='offset points', 
                size='large', ha='right', va='center')
    
    n.set_rotation(90)
    
    initial_bgc = scores_from_bgc[sample_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    #ax.set_xticks([])
    #ax.set_yticks([])
    #ax.set_yticklabels([x for x in ax.get_yticks()], rotation=45)

    ax.set_ylabel('IOKR score', size='medium')
    ax.set_xlabel('std. corr. score', size='medium')
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[row_idx, col_idx]
        ax.hist(score_set)
        #ax.set_xticks([])
        #ax.set_yticks([])
        #ax.set_yticklabels([int(x) for x in ax.get_yticks()], rotation=45)
        ax.set_xlabel('score', size='medium')
        ax.set_ylabel('count', size='medium')
        ax.scatter([actual_score], [0], zorder=4, color='r')
        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)



fig.tight_layout()

data = (sample_plot_indices, scores_from_bgc_idlist, scores_from_bgc)
with open(filename + '.data', 'wb') as f:
    pickle.dump(data, f)

plt.savefig(filename + '_top.png', dpi=1200)

# %%
# How many links score higher than the verified link?

# %%
# 11: retimycin, 14: lomaiviticin
sample_idx = 14
gcf, bgc, mibig = scores_from_bgc_idlist[sample_idx]
initial_bgc = scores_from_bgc[sample_idx]
score_set_metcalf_raw, actual_score_metcalf_raw = initial_bgc[2]
score_set_metcalf, actual_score_metcalf = initial_bgc[1]
score_set_iokr, actual_score_iokr = initial_bgc[0]

print('lomaiviticin A, BGC0000241')
print('total number of links', len(score_set_metcalf_raw))
print('Number of links with equal or higher raw corr. score:', len([x for x in score_set_metcalf_raw if x >= actual_score_metcalf_raw]))
print('Number of links with equal or higher raw corr. and IOKR scores:', len([x for x, y in zip(score_set_iokr, score_set_metcalf_raw) if y >= actual_score_metcalf_raw and x >= actual_score_iokr]))
print('Number of links with equal or higher correlation score:', len([x for x in score_set_metcalf if x >= actual_score_metcalf]))
print('Number of links with equal or higher corr. and IOKR scores:', len([x for x, y in zip(score_set_iokr, score_set_metcalf) if y >= actual_score_metcalf and x >= actual_score_iokr]))
print('Number of links with equal or higher IOKR score:', len([x for x in score_set_iokr if x >= actual_score_iokr]))

iokr_mean = numpy.mean(iokr_scores_all)
iokr_std = numpy.std(iokr_scores_all)
score_set_iokr_std = (score_set_iokr - iokr_mean) / iokr_std
actual_score_iokr_std = (actual_score_iokr - iokr_mean) / iokr_std
sum_scores = [numpy.sign(x) * numpy.sqrt(numpy.abs(x)) + numpy.sign(y) * numpy.sqrt(numpy.abs(y)) for x, y in zip(score_set_iokr_std, score_set_metcalf)]
sum_scores.sort(reverse=True)
sum_scores.index(
    numpy.sign(actual_score_iokr_std) * numpy.sqrt(numpy.abs(actual_score_iokr_std)) + 
    numpy.sign(actual_score_metcalf) * numpy.sqrt(numpy.abs(actual_score_metcalf))
)
# Out:
# lomaiviticin A, BGC0000241
# total number of links 3094
# Number of links with equal or higher raw corr. score: 22
# Number of links with equal or higher raw corr. and IOKR scores: 1
# Number of links with equal or higher correlation score: 16
# Number of links with equal or higher corr. and IOKR scores: 1
# Number of links with equal or higher IOKR score: 119
# 4

# %%
# 11: retimycin, 14: lomaiviticin
sample_idx = 11
gcf, bgc, mibig = scores_from_bgc_idlist[sample_idx]
initial_bgc = scores_from_bgc[sample_idx]
score_set_metcalf_raw, actual_score_metcalf_raw = initial_bgc[2]
score_set_metcalf, actual_score_metcalf = initial_bgc[1]
score_set_iokr, actual_score_iokr = initial_bgc[0]

print('retimycin A, BGC0001228')
print('total number of links', len(score_set_metcalf_raw))
print('Number of links with equal or higher raw corr. score:', len([x for x in score_set_metcalf_raw if x >= actual_score_metcalf_raw]))
print('Number of links with equal or higher raw corr. and IOKR scores:', len([x for x, y in zip(score_set_iokr, score_set_metcalf_raw) if y >= actual_score_metcalf_raw and x >= actual_score_iokr]))
print('Number of links with equal or higher correlation score:', len([x for x in score_set_metcalf if x >= actual_score_metcalf]))
print('Number of links with equal or higher corr. and IOKR scores:', len([x for x, y in zip(score_set_iokr, score_set_metcalf) if y >= actual_score_metcalf and x >= actual_score_iokr]))
print('Number of links with equal or higher IOKR score:', len([x for x in score_set_iokr if x >= actual_score_iokr]))

iokr_mean = numpy.mean(iokr_scores_all)
iokr_std = numpy.std(iokr_scores_all)
score_set_iokr_std = (score_set_iokr - iokr_mean) / iokr_std
actual_score_iokr_std = (actual_score_iokr - iokr_mean) / iokr_std
sum_scores = [numpy.sign(x) * numpy.sqrt(numpy.abs(x)) + numpy.sign(y) * numpy.sqrt(numpy.abs(y)) for x, y in zip(score_set_iokr_std, score_set_metcalf)]
sum_scores.sort(reverse=True)
sum_scores.index(
    numpy.sign(actual_score_iokr_std) * numpy.sqrt(numpy.abs(actual_score_iokr_std)) + 
    numpy.sign(actual_score_metcalf) * numpy.sqrt(numpy.abs(actual_score_metcalf))
)
# Out:
# retimycin A, BGC0001228
# total number of links 3094
# Number of links with equal or higher raw corr. score: 1089
# Number of links with equal or higher raw corr. and IOKR scores: 122
# Number of links with equal or higher correlation score: 1152
# Number of links with equal or higher corr. and IOKR scores: 141
# Number of links with equal or higher IOKR score: 384
# 252

# %%
# Rank of the verified link according to the scoring functions, and l_p combinations

# %%
def l_p(x, y, p):
    return numpy.sign(x) * numpy.power(numpy.abs(x), p) + numpy.sign(y) * numpy.power(numpy.abs(y), p)

l_p(1, 2, 0.5)
# Out:
# 2.414213562373095

# %%
# 11: retimycin, 14: lomaiviticin
results = []
for sample_idx in range(len(scores_from_bgc_idlist)):
    gcf, bgc, mibig = scores_from_bgc_idlist[sample_idx]
    initial_bgc = scores_from_bgc[sample_idx]
    score_set_metcalf_raw, actual_score_metcalf_raw = initial_bgc[2]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]

    # print('retimycin A, BGC0001228')
    total = len(score_set_metcalf_raw)
    higher_corr_raw = len([x for x in score_set_metcalf_raw if x >= actual_score_metcalf_raw])
    higher_both_raw = len([x for x, y in zip(score_set_iokr, score_set_metcalf_raw) if y >= actual_score_metcalf_raw and x >= actual_score_iokr])
    higher_corr = len([x for x in score_set_metcalf if x >= actual_score_metcalf])
    higher_both = len([x for x, y in zip(score_set_iokr, score_set_metcalf) if y >= actual_score_metcalf and x >= actual_score_iokr])
    higher_iokr = len([x for x in score_set_iokr if x >= actual_score_iokr])


    iokr_mean = numpy.mean(iokr_scores_all)
    iokr_std = numpy.std(iokr_scores_all)
    score_set_iokr_std = (score_set_iokr - iokr_mean) / iokr_std
    actual_score_iokr_std = (actual_score_iokr - iokr_mean) / iokr_std
    
    sum_scores = [l_p(x, y, 0.5) for x, y in zip(score_set_iokr_std, score_set_metcalf)]
    sum_scores.sort(reverse=True)
    rank_index_12 = len([x for x in sum_scores if x >= l_p(actual_score_iokr_std, actual_score_metcalf, 0.5)])
    
    sum_scores = [l_p(x, y, 2) for x, y in zip(score_set_iokr_std, score_set_metcalf)]
    sum_scores.sort(reverse=True)
    rank_index_2 = len([x for x in sum_scores if x >= l_p(actual_score_iokr_std, actual_score_metcalf, 2)])
    
    sum_scores = [l_p(x, y, 1) for x, y in zip(score_set_iokr_std, score_set_metcalf)]
    sum_scores.sort(reverse=True)
    rank_index_1 = len([x for x in sum_scores if x >= l_p(actual_score_iokr_std, actual_score_metcalf, 1)])

    results.append((mibig, higher_iokr, higher_corr, rank_index_12, rank_index_1, rank_index_2, higher_both))

# %%
for r in results:
    print(r)
# Out:
# ('BGC0000137', 80, 16, 2, 14, 49, 1)
# ('BGC0000137', 78, 189, 12, 29, 66, 3)
# ('BGC0000137', 798, 1968, 1232, 997, 920, 534)
# ('BGC0000137', 636, 612, 409, 642, 735, 120)
# ('BGC0000137', 6, 287, 36, 214, 261, 1)
# ('BGC0000137', 6, 126, 14, 105, 122, 1)
# ('BGC0000137', 6, 216, 4, 85, 203, 1)
# ('BGC0000137', 184, 282, 146, 271, 285, 17)
# ('BGC0000137', 184, 101, 28, 92, 99, 7)
# ('BGC0000137', 184, 90, 19, 89, 88, 7)
# ('BGC0000333', 1810, 25, 32, 12, 12, 12)
# ('BGC0001228', 384, 1152, 253, 271, 317, 141)
# ('BGC0000827', 6, 1, 2, 1, 1, 1)
# ('BGC0001830', 673, 7, 7, 9, 24, 4)
# ('BGC0000241', 119, 16, 5, 12, 14, 1)

# %%
# Plot of the unit circle in the l_p "norms"

# %%
x = numpy.linspace(-1.0, 1.0, 100)
y = numpy.linspace(-1.0, 1.0, 100)

fig, axes = plt.subplots(ncols=3, figsize=(8, 4))

X0, Y0 = numpy.meshgrid(x, y)
F0 = numpy.sqrt(numpy.abs(X0)) + numpy.sqrt(numpy.abs(Y0)) - 1.0

X1, Y1 = numpy.meshgrid(x, y)
F1 = numpy.abs(X1) + numpy.abs(Y1) - 1.0

X2, Y2 = numpy.meshgrid(x,y)
F2 = X2**2 + Y2**2 - 1.0

eqn_list = (
    ('$\ell_\\frac{1}{2}$', F0),
    ('$\ell_1$', F1),
    ('$\ell_2$', F2)
)

for ax, eqn_pair in zip(axes, eqn_list):
    eqn_title, eqn = eqn_pair

    ax.set_title(eqn_title, size=18)
    
    ax.contour(X,Y,eqn,[0])

    ax.set_aspect(1)

    ax.set_xlim(-1.25,1.25)
    ax.set_ylim(-1.25,1.25)
    
    ax.set_yticks([-1, 0, 1])

    plt.grid(linestyle='--')
    
plt.tight_layout()

plt.savefig('fig_norms.pdf')

# %%
# Plots for all of the BGCs that are part of established links

# %%
fig, axes = plt.subplots(nrows=15, ncols=4, figsize=(9, 25))

filename = '20210331_bgc_scores_crusemann'

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)

pad = 5
    
for row_idx in range(len(scores_from_bgc)):
    gcf, bgc, mibig = scores_from_bgc_idlist[row_idx]
    # axes[row_idx, 0].set_ylabel(mibig)
    ax = axes[row_idx, 0]
    n = ax.annotate(mibig, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0), 
                xycoords=ax.yaxis.label, textcoords='offset points', 
                size='large', ha='right', va='center')
    n.set_rotation(90)


    initial_bgc = scores_from_bgc[row_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    #ax.set_xticks([])
    #ax.set_yticks([])
    
    ax.set_ylabel('IOKR score', size='medium')
    ax.set_xlabel('std. corr. score', size='medium')
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[row_idx, col_idx]
        ax.hist(score_set)
        ax.scatter([actual_score], [0], zorder=3, color='r')
        #ax.set_xticks([])
        #ax.set_yticks([])
        ax.set_xlabel('score', size='medium')
        ax.set_ylabel('count', size='medium')

        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)

fig.tight_layout()

plt.savefig(filename + '_all.png')

# %%
# 15 in total -- 8 + 7
# first part
nrows = 8
figheight = 25 / 15 * nrows
fig, axes = plt.subplots(nrows=nrows, ncols=4, figsize=(9, figheight))

filename = '20210331_bgc_scores_crusemann_part1'

pad = 5

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)

#for row_idx in range(len(scores_from_bgc)):
for row_idx in range(8):
    gcf, bgc, mibig = scores_from_bgc_idlist[row_idx]
    #axes[row_idx, 0].set_ylabel(mibig)
    ax = axes[row_idx, 0]
    n = ax.annotate(mibig, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0), 
                xycoords=ax.yaxis.label, textcoords='offset points', 
                size='large', ha='right', va='center')
    n.set_rotation(90)


    initial_bgc = scores_from_bgc[row_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    ax.set_ylabel('IOKR score', size='medium')
    ax.set_xlabel('std. corr. score', size='medium')

    #ax.set_xticks([])
    #ax.set_yticks([])
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[row_idx, col_idx]
        ax.hist(score_set)
        ax.scatter([actual_score], [0], zorder=3, color='r')
        #ax.set_xticks([])
        #ax.set_yticks([])
        ax.set_xlabel('score', size='medium')
        ax.set_ylabel('count', size='medium')

        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)

fig.tight_layout()

plt.savefig(filename + '_all.png')

# %%
# second part
row_offset = 8
nrows = 7
figheight = 25 / 15 * nrows
fig, axes = plt.subplots(nrows=nrows, ncols=4, figsize=(9, figheight))

filename = '20210331_bgc_scores_crusemann_part2'

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)
    
pad = 5

#for row_idx in range(len(scores_from_bgc)):
graph_row_idx = 0
for row_idx in range(8, 15):
    gcf, bgc, mibig = scores_from_bgc_idlist[row_idx]
    #axes[graph_row_idx, 0].set_ylabel(mibig)
    ax = axes[graph_row_idx, 0]
    n = ax.annotate(mibig, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0), 
                xycoords=ax.yaxis.label, textcoords='offset points', 
                size='large', ha='right', va='center')
    n.set_rotation(90)

    initial_bgc = scores_from_bgc[row_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[graph_row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    #ax.set_xticks([])
    #ax.set_yticks([])
    ax.set_ylabel('IOKR score', size='medium')
    ax.set_xlabel('std. corr. score', size='medium')
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[graph_row_idx, col_idx]
        ax.hist(score_set)
        ax.scatter([actual_score], [0], zorder=3, color='r')
        #ax.set_xticks([])
        #ax.set_yticks([])
        ax.set_xlabel('score', size='medium')
        ax.set_ylabel('count', size='medium')
        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[graph_row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)
        
    graph_row_idx += 1

fig.tight_layout()

plt.savefig(filename + '_all.png')

# %%
all_score_objects = []

for i, gcf in enumerate(npl.gcfs):
    print("{} / {}".format(i, len(npl.gcfs)))
    
    for mf in npl.molfams:
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
        iokr_score = get_iokr_score(mf, gcf)
        
        all_score_objects.append((metcalf_score, iokr_score))
# Out:
# 0 / 454
# 1 / 454
# 2 / 454
# 3 / 454
# 4 / 454
# 5 / 454
# 6 / 454
# 7 / 454
# 8 / 454
# 9 / 454
# 10 / 454
# 11 / 454
# 12 / 454
# 13 / 454
# 14 / 454
# 15 / 454
# 16 / 454
# 17 / 454
# 18 / 454
# 19 / 454
# 20 / 454
# 21 / 454
# 22 / 454
# 23 / 454
# 24 / 454
# 25 / 454
# 26 / 454
# 27 / 454
# 28 / 454
# 29 / 454
# 30 / 454
# 31 / 454
# 32 / 454
# 33 / 454
# 34 / 454
# 35 / 454
# 36 / 454
# 37 / 454
# 38 / 454
# 39 / 454
# 40 / 454
# 41 / 454
# 348 / 454
# 349 / 454
# 350 / 454
# 351 / 454
# 352 / 454
# 353 / 454
# 354 / 454
# 355 / 454
# 356 / 454
# 357 / 454
# 358 / 454
# 359 / 454
# 360 / 454
# 361 / 454
# 362 / 454
# 363 / 454
# 364 / 454
# 365 / 454
# 366 / 454
# 367 / 454
# 368 / 454
# 369 / 454
# 370 / 454
# 371 / 454
# 372 / 454
# 373 / 454
# 374 / 454
# 375 / 454
# 376 / 454
# 377 / 454
# 378 / 454
# 379 / 454
# 380 / 454
# 381 / 454
# 382 / 454
# 383 / 454
# 384 / 454
# 385 / 454
# 386 / 454
# 387 / 454
# 388 / 454
# 389 / 454
# 390 / 454
# 391 / 454
# 392 / 454
# 393 / 454
# 394 / 454
# 395 / 454
# 396 / 454
# 397 / 454
# 398 / 454
# 399 / 454
# 400 / 454
# 401 / 454
# 402 / 454
# 403 / 454
# 404 / 454
# 405 / 454
# 406 / 454
# 407 / 454
# 408 / 454
# 409 / 454
# 410 / 454
# 411 / 454
# 412 / 454
# 413 / 454
# 414 / 454
# 415 / 454
# 416 / 454
# 417 / 454
# 418 / 454
# 419 / 454
# 420 / 454
# 421 / 454
# 422 / 454
# 423 / 454
# 424 / 454
# 425 / 454
# 426 / 454
# 427 / 454
# 428 / 454
# 429 / 454
# 430 / 454
# 431 / 454
# 432 / 454
# 433 / 454
# 434 / 454
# 435 / 454
# 436 / 454
# 437 / 454
# 438 / 454
# 439 / 454
# 440 / 454
# 441 / 454
# 442 / 454
# 443 / 454
# 444 / 454
# 445 / 454
# 446 / 454
# 447 / 454
# 448 / 454
# 449 / 454
# 450 / 454
# 451 / 454
# 452 / 454
# 453 / 454

# %%
iokr_scores = [x[1] for x in all_score_objects if x[1] != -100]
metcalf_scores = [x[0] for x in all_score_objects if x[1] != -100]
filtered_object_pairs = [x for y, x in zip(all_score_objects, all_object_pairs) if y[1] != -100]

iokr_mean = numpy.mean(iokr_scores)
iokr_std = numpy.std(iokr_scores)
iokr_scores_std = (iokr_scores - iokr_mean) / iokr_std

l12_scores = [l_p(x, y, 0.5) for x, y in zip(iokr_scores_std, metcalf_scores)]

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(metcalf_scores, iokr_scores)
plt.show()

# %%
l12_scores_index = list(enumerate(l12_scores))
l12_scores_index.sort(key=lambda x:x[1], reverse=True)

# %%
[x[1] for x in l12_scores_index][:10]
# Out:
# [5.686555646623231,
#  5.531695257002806,
#  5.349561659294869,
#  5.300799938946047,
#  5.284026680935494,
#  5.280615926386468,
#  5.2758386063877625,
#  5.1580258276417315,
#  5.142451156157339,
#  5.077736782108527]

# %%
plt.figure(figsize=(8, 8))
plt.scatter(metcalf_scores, iokr_scores_std)

indices = [x[0] for x in l12_scores_index[:5]]
plt.scatter([metcalf_scores[x] for x in indices], [iokr_scores_std[x] for x in indices], color='r')

plt.savefig('crusemann_top5_l12.png')
plt.show()

# %%
import pyteomics.mgf

# %%
spectra_dict = {}
with pyteomics.mgf.read('/home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/METABOLOMICS-SNETS-9360fa51-download_clustered_spectra-main.mgf', 'r') as spectra:
    for s in spectra:
        spectrum_id = int(s['params']['title'].split(': ')[-1])
        spectra_dict[spectrum_id] = s

# %%
for i,s in spectra_dict.items():
    # print(i, s['params']['title'], s['params']['scans'])
    if str(i) != s['params']['scans']:
        print(s)
        break

# %%
cnt = 0
visualisation_url = "https://metabolomics-usi.ucsd.edu/spectrum/?usi=mzspec:GNPS:TASK-{}-spectra/specs_ms.mgf:scan:{}"
crusemann_id = "9360fa514804487a9d39b7e7d7e6d514"

extra_data = {
      0: """  class: Aminocoumarin (?Phosphonate)
  MIBiG ID: BGC0000938 (?BGC0001859)
""",
    1: """  class: Polyketide
  MIBiG ID: BGC0001830
""",
    2: """  class: Polyketide
  MIBiG ID: BGC0001828
""",
    3: """  class: Saccharide
  MIBiG ID: BGC0000719 BGC0000720 BGC0000721
""",
    4: """  class: Polyketide
  MIBiG ID: BGC0001830
"""
}

for index, l_score in l12_scores_index[:5]:
    filename = 'potential_link_{}'.format(cnt)
    
    corr_score = metcalf_scores[index]
    std_iokr = iokr_scores_std[index]
    iokr = iokr_scores[index]
    gcf, mf = filtered_object_pairs[index]
    
    output = []
    output.append('pair index {}'.format(index))
    
    output.append('std_corr: {}'.format(corr_score))
    output.append('iokr: {}'.format(iokr))
    output.append('std_iokr: {}'.format(std_iokr))
    
    output.append('')
    
    output.append('GCF size: {}'.format(len(gcf.strains._strains)))
    output.append('MF size: {}'.format(len(set(strains._strains).intersection(mf.strains))))
    output.append('intersection size: {}'.format(len(set(gcf.strains._strains).intersection(mf.strains))))
    
    output.append('')
    
    output.append('GCF')
    output.append('bgc list:')
    for bgc in gcf.bgcs:
        output.append('  {} - {}'.format(bgc.strain, bgc.name))
        output.append('  associated names: {}'.format(set.union(*[structures_to_names[x] for x in bgc_smiles_lookup[bgc]])))
    if cnt in extra_data:
        output.append(extra_data[cnt])
    
    output.append('')
    output.append('MF')
    output.append('id: {}'.format(mf.family_id))
    print(mf.family_id)
    #print(len(mf.spectra))
    mf_spectra = [spectra_dict[x.spectrum_id] for x in mf.spectra]
    if os.path.exists(filename + '.mgf'):
        os.remove(filename + '.mgf')
    pyteomics.mgf.write(mf_spectra, filename + '.mgf')

    for spectrum in mf.spectra:
        output.append('  spectrum {}'.format(spectrum.spectrum_id) + '--' + visualisation_url.format(crusemann_id, spectrum.spectrum_id))
        if cnt == 1:
            print(spectrum)
            print(spectrum.precursor_mz, spectrum.parent_mz)
    output.append('strains:')
    for s in mf.strains:
        if s in strains:
            output.append('  ' + str(s))

            
    with open(filename + '.txt', 'w') as f:
        f.writelines([x + '\n' for x in output])
            
            
    cnt += 1
# Out:
# -1
# -1
# Spectrum(id=3504, spectrum_id=68403, strains=9)
# 613.49298 613.49298
# 58
# -1
# 334

# %%
max_id = 0
for mf in npl.molfams:
    for spectrum in mf.spectra:
        max_id = max(spectrum.spectrum_id, max_id)
max_id
# Out:
# 124733

# %%
dir(spectrum)
# Out:
# ['__class__',
#  '__cmp__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_jcamp',
#  '_losses',
#  'add_strain',
#  'annotations',
#  'dataset_strains',
#  'edges',
#  'family',
#  'family_id',
#  'get_growth_medium',
#  'get_metadata_value',
#  'gnps_annotations',
#  'gnps_id',
#  'has_annotations',
#  'has_loss',
#  'has_strain',
#  'id',
#  'is_library',
#  'keep_top_k',
#  'losses',
#  'max_ms2_intensity',
#  'metadata',
#  'n_peaks',
#  'normalised_peaks',
#  'parent_mz',
#  'peaks',
#  'precursor_mz',
#  'rt',
#  'set_annotations',
#  'spectrum_id',
#  'strain_list',
#  'strain_set',
#  'strains',
#  'to_jcamp_str',
#  'total_ms2_intensity']

# %%
structures_to_names = {}
with open(mibig_molecular_structures) as f:
    r = csv.reader(f)
    for line in r:
        bgc_id, compound_name, smiles, database_ids = line
        if not bgc_id.startswith('BGC'):
            continue
        if smiles in structures_to_names:
            structures_to_names[smiles].add(compound_name)
        else:
            structures_to_names[smiles] = set([compound_name])

# %%
mf_strain_counter = []
gcf_strain_counter = []
for mf in npl.molfams:
    mf_strain_counter.append(len(mf.strains))
for gcf in npl.gcfs:
    gcf_strain_counter.append(len(gcf.strains))

# %%
import collections

# %%
collections.Counter(mf_strain_counter)
# Out:
# Counter({1: 899,
#          0: 142,
#          14: 19,
#          32: 2,
#          101: 1,
#          11: 11,
#          62: 2,
#          69: 1,
#          26: 3,
#          2: 1157,
#          15: 4,
#          55: 2,
#          5: 93,
#          17: 9,
#          7: 43,
#          123: 1,
#          4: 164,
#          6: 64,
#          24: 3,
#          3: 284,
#          10: 17,
#          20: 8,
#          40: 3,
#          23: 4,
#          9: 23,
#          22: 3,
#          48: 3,
#          16: 5,
#          8: 35,
#          34: 2,
#          12: 14,
#          25: 6,
#          88: 1,
#          31: 2,
#          92: 1,
#          46: 2,
#          111: 1,
#          106: 1,
#          78: 1,
#          51: 1,
#          37: 1,
#          45: 2,
#          18: 6,
#          58: 2,
#          13: 8,
#          38: 2,
#          28: 1,
#          81: 1,
#          19: 5,
#          21: 3,
#          27: 2,
#          35: 2,
#          29: 3,
#          107: 1,
#          67: 2,
#          33: 2,
#          44: 3,
#          109: 1,
#          36: 2,
#          116: 1,
#          73: 1,
#          80: 1,
#          57: 2,
#          74: 1,
#          83: 1,
#          72: 1})

# %%
collections.Counter(gcf_strain_counter)
# Out:
# Counter({28: 2,
#          44: 1,
#          1: 184,
#          2: 48,
#          3: 28,
#          17: 4,
#          6: 12,
#          23: 2,
#          60: 1,
#          5: 15,
#          11: 8,
#          19: 3,
#          4: 12,
#          10: 7,
#          22: 6,
#          26: 3,
#          48: 1,
#          14: 6,
#          15: 13,
#          58: 2,
#          8: 9,
#          39: 6,
#          7: 6,
#          12: 12,
#          21: 5,
#          20: 9,
#          37: 3,
#          27: 1,
#          16: 6,
#          50: 1,
#          55: 1,
#          67: 1,
#          24: 3,
#          38: 2,
#          47: 1,
#          25: 4,
#          13: 4,
#          61: 2,
#          40: 1,
#          35: 3,
#          46: 1,
#          18: 3,
#          9: 3,
#          52: 1,
#          54: 1,
#          57: 1,
#          73: 1,
#          68: 1,
#          31: 1,
#          102: 1,
#          32: 1,
#          59: 1})
