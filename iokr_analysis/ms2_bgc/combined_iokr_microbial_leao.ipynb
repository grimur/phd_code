# %%
# %load_ext autoreload
# %autoreload 2

# %%
import csv
import numpy
import os

# %%
import sys

# %%
sys.path.append('/home/grimur/git/nplinker/nplinker/prototype')

# %%
from nplinker import nplinker
from nplinker import logconfig
logconfig.LogConfig.setLogLevel('DEBUG')

# %%
nplinker_data_path = '/home/grimur/iokr_verify_data/gerwick.toml'
# gnps_spectrum_file = "/home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/clusterinfosummarygroup_attributes_withIDs_withcomponentID/b270f7e260f34e808ead3f642784b672.tsv"

# %%
npl = nplinker.NPLinker(nplinker_data_path)
npl.load_data()
# Out:
# 13:21:01 [DEBUG] config.py:71, Parsing default config file: /home/grimur/.config/nplinker/nplinker.toml
# 13:21:01 [DEBUG] config.py:74, Loading user config /home/grimur/iokr_verify_data/gerwick.toml
# 13:21:01 [INFO] config.py:106, Loading from local data in directory /home/grimur/iokr_verify_data/gerwick
# 13:21:01 [DEBUG] loader.py:129, DatasetLoader(/home/grimur/iokr_verify_data/gerwick, , False)
# 13:21:01 [DEBUG] nplinker.py:119, Enabled scoring method: metcalf
# 13:21:01 [DEBUG] nplinker.py:119, Enabled scoring method: testscore
# 13:21:01 [DEBUG] nplinker.py:119, Enabled scoring method: rosetta
# 13:21:01 [DEBUG] nplinker.py:240, load_data (normal case, full load, met_only=False)
# 13:21:01 [WARNING] loader.py:31, WARNING: unable to find extra_nodes_file in path "/home/grimur/iokr_verify_data/gerwick/quantification_table_reformatted/*.csv"
# 13:21:01 [WARNING] loader.py:31, WARNING: unable to find metadata_table_file in path "/home/grimur/iokr_verify_data/gerwick/metadata_table/metadata_table*.txt"
# 13:21:01 [WARNING] loader.py:31, WARNING: unable to find quantification_table_file in path "/home/grimur/iokr_verify_data/gerwick/quantification_table/quantification_table*.csv"
# 13:21:02 [INFO] loader.py:448, Loaded global strain IDs (162 total)
# 13:21:02 [INFO] loader.py:459, Loaded dataset strain IDs (166 total)
# 13:21:02 [INFO] metabolomics.py:634, 173 molecules parsed from MGF file
# 13:21:02 [DEBUG] metabolomics.py:331, loading edges file: /home/grimur/iokr_verify_data/gerwick/networkedges_selfloop/2fd76d830a6c49bd84ffaa71f6936a3b..selfloop [173 spectra from MGF]
# 13:21:02 [DEBUG] metabolomics.py:644, Nodes_file: /home/grimur/iokr_verify_data/gerwick/clusterinfosummarygroup_attributes_withIDs_withcomponentID/f7d5b4159b824739a7292e4461332b61.clustersummary, quant_table_exists?: True
# 13:21:02 [INFO] metabolomics.py:651, Found older-style GNPS dataset, no quantification table
# 13:21:02 [DEBUG] metabolomics.py:692, make_families: 22 molams + 68 singletons
# 13:21:02 [INFO] loader.py:434, Loading provided annotation files (/home/grimur/iokr_verify_data/gerwick/result_specnets_DB)
# 13:21:02 [DEBUG] annotations.py:57, Parsed 0 annotations configuration entries
# 13:21:02 [DEBUG] annotations.py:65, Found 1 annotations .tsv files in /home/grimur/iokr_verify_data/gerwick/result_specnets_DB
# 13:21:02 [DEBUG] annotations.py:74, Parsing GNPS annotations from /home/grimur/iokr_verify_data/gerwick/result_specnets_DB/c1881da809cd4516bc1dbe11161bb752.tsv
# 13:21:02 [DEBUG] loader.py:298, Collecting .gbk files (and possibly renaming)
# 13:21:02 [DEBUG] loader.py:317, .gbk collection took 0.218s
# 13:21:02 [INFO] loader.py:318, 0/151 .gbk files were renamed to remove spaces!
# 13:21:02 [DEBUG] loader.py:327, make_mibig_bgc_dict(/home/grimur/iokr_verify_data/gerwick/mibig_json)
# 13:21:02 [INFO] genomics.py:384, Found 1816 MiBIG json files
# 13:21:02 [DEBUG] loader.py:329, mibig_bgc_dict has 1816 entries
# 13:21:03 [WARNING] loader.py:366, 1 missing annotation tsv files:
# 13:21:03 [WARNING] loader.py:368,   1/1: /home/grimur/iokr_verify_data/gerwick/bigscape/network_files/2020-03-05_09-49-06_hybrids_glocal/Saccharides/Network_Annotations_Saccharides.tsv
# 13:21:03 [WARNING] loader.py:366, 1 missing clustering tsv files:
# 13:21:03 [WARNING] loader.py:368,   1/1: /home/grimur/iokr_verify_data/gerwick/bigscape/network_files/2020-03-05_09-49-06_hybrids_glocal/Saccharides/Saccharides_clustering_c0.30.tsv
# 13:21:03 [WARNING] loader.py:366, 1 missing network files:
# 13:21:03 [WARNING] loader.py:368,   1/1: /home/grimur/iokr_verify_data/gerwick/bigscape/network_files/2020-03-05_09-49-06_hybrids_glocal/Saccharides/Saccharides_c0.30.network
# 13:21:03 [WARNING] loader.py:382, Product type Saccharides will be skipped due to missing files!
# 13:21:03 [DEBUG] loader.py:389, Generating antiSMASH filename cache...
# 13:21:03 [DEBUG] loader.py:398, Cache generation took 0.001s
# 13:21:03 [DEBUG] loader.py:400, loadBGC_from_cluster_files(antismash_dir=/home/grimur/iokr_verify_data/gerwick/antismash-5b, delimiters=['.', '_', '-'])
# 13:21:03 [INFO] genomics.py:190, Using antiSMASH filename delimiters ['.', '_', '-']
# 13:21:03 [INFO] genomics.py:291, # MiBIG BGCs = 0, non-MiBIG BGCS = 1963, total bgcs = 1963, GCFs = 110, strains=1982
# 13:21:03 [INFO] genomics.py:348, Filtering MiBIG BGCs: removing 0 GCFs and 0 BGCs
# 13:21:03 [INFO] genomics.py:298, # after filtering, total bgcs = 147, GCFs = 110, strains=166
# 13:21:03 [DEBUG] genomics.py:302, Loading .network files
# 13:21:03 [INFO] loader.py:251, Strains filtered down to total of 4
# 13:21:03 [DEBUG] nplinker.py:264, Generating lookup tables: genomics
# 13:21:03 [DEBUG] nplinker.py:276, Generating lookup tables: metabolomics
# 13:21:03 [DEBUG] nplinker.py:285, load_data: completed
# True

# %%
# Assign known_cluster_blast hits to BGCs

# %%
from nplinker.parsers.kcb import KCBParser

# %%
kkb_bgc_hits = {}
for bgc in npl.bgcs:
    kcb_filename = KCBParser.get_kcb_filename_from_bgc(bgc)
    kcb_parser = KCBParser(kcb_filename)
    hits = []
    for mibig_id, hit in kcb_parser.hits.items():
        score = numpy.sum([x['blast_score'] for x in hit['individual_hits']])
        hits.append((mibig_id, score))
    if len(hits) > 0:
        kkb_bgc_hits[bgc] = hits

# %%
print(len(kkb_bgc_hits))
# Out:
# 69

# %%
# Define the links to look for
# These are the links from the paired data platform - so, _verified_ links!!!

# %%
established_links = [
    ('3L', 'BGC0001165', 28),  # Curacin A --- 3L
    ('3L', 'BGC0000962', 80),  # Barbamide --- 3L 
    ('JHB', 'BGC0001000', 198),  # Hectochlorine --- JHB
    ('JHB', 'BGC0001001', 112),  # Jamaicamide A-C
    ('JHB', 'BGC0001560', 52)  # Cryptomaldamide
]

# %%
established_link_objects_ids = []
established_link_objects = []
for bgc, kkb_hits in kkb_bgc_hits.items():
    for strain_id, mibig_id, spectrum_id in established_links:
        if strain_id == bgc.strain.id or strain_id in bgc.strain.aliases:
            if mibig_id in [x[0] for x in kkb_hits if x[1] > 10000]:
                for spectrum in npl.spectra:
                    if spectrum.spectrum_id == spectrum_id:
                        spectrum_strain_ids = set([x.id for x in spectrum.strains])
                        for x in spectrum.strains:
                            spectrum_strain_ids = spectrum_strain_ids.union(x.aliases)
                        if strain_id not in spectrum_strain_ids:
                            continue
                        print(strain_id, mibig_id, spectrum.spectrum_id)
                        established_link_objects.append((bgc, spectrum))
                        established_link_objects_ids.append((bgc.name, spectrum.spectrum_id))
# Out:
# 3L BGC0001165 28
# JHB BGC0001000 198
# JHB BGC0001560 52
# JHB BGC0001001 112
# JHB BGC0001001 112
# 3L BGC0000962 80
# 3L BGC0001165 28

# %%
print(len(established_link_objects))
print(len(established_link_objects_ids))
# Out:
# 7
# 7

# %%
print(established_link_objects_ids[0])
print(established_link_objects_ids[3])
# Out:
# ('NZ_MKZR01000001.region023', 28)
# ('NZ_CP017708.1.region023', 112)

# %%
datapath = '/home/grimur/git/nplinker/nplinker/prototype/nplinker/scoring/iokr/data'

spectra = datapath + os.sep + "spectra.txt"
spectra_folder = datapath + os.sep + 'SPEC'

# %%
import spectrum_filters
spectrum_filters.datapath = datapath
import spectrum

# %%
test_set_spectra = []
for npl_s in npl.spectra:
    ms = spectrum.MSSpectrum()
    ms.correct_for_ionisation = True
    ms.normalise = True
    ms.filter = spectrum_filters.filter_by_frozen_dag
    ms.init_from_spec(npl_s)
    test_set_spectra.append((ms, npl_s.spectrum_id))

# %%
# Need the training data server to process the test word vecs!

# %%
import metabolite
metabolite_server = metabolite.MetaboliteServer()
# Out:
# ['/home/grimur/miniconda2/envs/jupyter-py3/lib/python3.7/site-packages/cdk_pywrapper']
# Server process already running: True

# %%
# load bgcs

# %%
import bgc

mibig_structure_file = "/home/grimur/_iokr/data/mibig/compunds_structures_1.4.csv"
pfs_data_dir = "/home/grimur/mibig_kernel_test/cache/pfs"

bgc_corpus = bgc.load_data_dir(mibig_structure_file, pfs_data_dir)
# Out:
# building word vectors from 2236 words

# %%
pfs_dir = '/home/grimur/iokr_verify_data/gerwick/bigscape/cache/pfs'

# %%
sum(bgc_corpus.to_wv(['PF00975.19']))
# Out:
# 1

# %%
def read_bgc_domains(bgc_name):
    pfs_file = pfs_dir + os.sep + bgc_name + '.pfs'
    with open(pfs_file, 'r') as f:
        line = f.read()
        domains = line.split()
    return domains
    
wv = read_bgc_domains(npl.bgcs[0].name)
print(sum(bgc_corpus.to_wv(wv)))
# Out:
# 27

# %%
test_set_bgcs = []
for bgc in npl.bgcs:
    domains = read_bgc_domains(bgc.name)
    wv = bgc_corpus.to_wv(domains)
    test_set_bgcs.append((wv, bgc.name))

# %%
# test_set_bgcs
# test_set_spectra
# established_link_objects_ids

# %%
bgc_list = bgc_corpus.documents

bgc_training_set_wv = []
bgc_training_set_metabolites = []
bgc_training_set_ids = []

count = 0
for bgc_item in bgc_list:
    count += 1
    # sort of expect 50% increase in success due to multiple structures for BGCs
    if count % 100 == 0:
        print('{} / {}, {} success'.format(count, len(bgc_list), len(bgc_training_set_metabolites)))
    for structure in bgc_item.metabolites:
        try:
            metabolite_server.add_metabolite(structure)
            success = True
        except:
            success = False

        if success:
            bgc_training_set_wv.append(bgc_item.word_vector)
            bgc_training_set_metabolites.append(structure)
            bgc_training_set_ids.append(bgc_item.bgc_id)
# Out:
# 100 / 1200, 143 success
# 200 / 1200, 276 success
# 300 / 1200, 401 success
# 400 / 1200, 551 success
# 500 / 1200, 689 success
# 600 / 1200, 857 success
# 700 / 1200, 1009 success
# 800 / 1200, 1125 success
# 900 / 1200, 1236 success
# 1000 / 1200, 1373 success
# 1100 / 1200, 1540 success
# 1200 / 1200, 1682 success

# %%
import bgc

# %%
print('calculate kernel')
total = len(bgc_training_set_wv) ** 2 / 2
count = 0
K_z = numpy.zeros((len(bgc_training_set_wv), len(bgc_training_set_wv)))
for v1_idx in range(len(bgc_training_set_wv)):
    for v2_idx in range(v1_idx + 1):
        count += 1
        if count % 10000 == 0:
            print('{} / {}'.format(count, total))
        v1 = bgc_training_set_wv[v1_idx]
        v2 = bgc_training_set_wv[v2_idx]
        k_v1_v2 = bgc.wv_kernel(v1, v2)
        K_z[v1_idx, v2_idx] = k_v1_v2
        K_z[v2_idx, v1_idx] = k_v1_v2
# Out:
# calculate kernel
# 10000 / 1416244.5
# 20000 / 1416244.5
# 30000 / 1416244.5
# 40000 / 1416244.5
# 50000 / 1416244.5
# 60000 / 1416244.5
# 70000 / 1416244.5
# 80000 / 1416244.5
# 90000 / 1416244.5
# 100000 / 1416244.5
# 110000 / 1416244.5
# 120000 / 1416244.5
# 130000 / 1416244.5
# 140000 / 1416244.5
# 150000 / 1416244.5
# 160000 / 1416244.5
# 170000 / 1416244.5
# 180000 / 1416244.5
# 190000 / 1416244.5
# 200000 / 1416244.5
# 210000 / 1416244.5
# 220000 / 1416244.5
# 230000 / 1416244.5
# 240000 / 1416244.5
# 250000 / 1416244.5
# 260000 / 1416244.5
# 270000 / 1416244.5
# 280000 / 1416244.5
# 290000 / 1416244.5
# 300000 / 1416244.5
# 310000 / 1416244.5
# 320000 / 1416244.5
# 330000 / 1416244.5
# 340000 / 1416244.5
# 350000 / 1416244.5
# 360000 / 1416244.5
# 370000 / 1416244.5
# 380000 / 1416244.5
# 390000 / 1416244.5
# 400000 / 1416244.5
# 410000 / 1416244.5
# 420000 / 1416244.5
# 430000 / 1416244.5
# 440000 / 1416244.5
# 450000 / 1416244.5
# 460000 / 1416244.5
# 470000 / 1416244.5
# 480000 / 1416244.5
# 490000 / 1416244.5
# 500000 / 1416244.5
# 510000 / 1416244.5
# 520000 / 1416244.5
# 530000 / 1416244.5
# 540000 / 1416244.5
# 550000 / 1416244.5
# 560000 / 1416244.5
# 570000 / 1416244.5
# 580000 / 1416244.5
# 590000 / 1416244.5
# 600000 / 1416244.5
# 610000 / 1416244.5
# 620000 / 1416244.5
# 630000 / 1416244.5
# 640000 / 1416244.5
# 650000 / 1416244.5
# 660000 / 1416244.5
# 670000 / 1416244.5
# 680000 / 1416244.5
# 690000 / 1416244.5
# 700000 / 1416244.5
# 710000 / 1416244.5
# 720000 / 1416244.5
# 730000 / 1416244.5
# 740000 / 1416244.5
# 750000 / 1416244.5
# 760000 / 1416244.5
# 770000 / 1416244.5
# 780000 / 1416244.5
# 790000 / 1416244.5
# 800000 / 1416244.5
# 810000 / 1416244.5
# 820000 / 1416244.5
# 830000 / 1416244.5
# 840000 / 1416244.5
# 850000 / 1416244.5
# 860000 / 1416244.5
# 870000 / 1416244.5
# 880000 / 1416244.5
# 890000 / 1416244.5
# 900000 / 1416244.5
# 910000 / 1416244.5
# 920000 / 1416244.5
# 930000 / 1416244.5
# 940000 / 1416244.5
# 950000 / 1416244.5
# 960000 / 1416244.5
# 970000 / 1416244.5
# 980000 / 1416244.5
# 990000 / 1416244.5
# 1000000 / 1416244.5
# 1010000 / 1416244.5
# 1020000 / 1416244.5
# 1030000 / 1416244.5
# 1040000 / 1416244.5
# 1050000 / 1416244.5
# 1060000 / 1416244.5
# 1070000 / 1416244.5
# 1080000 / 1416244.5
# 1090000 / 1416244.5
# 1100000 / 1416244.5
# 1110000 / 1416244.5
# 1120000 / 1416244.5
# 1130000 / 1416244.5
# 1140000 / 1416244.5
# 1150000 / 1416244.5
# 1160000 / 1416244.5
# 1170000 / 1416244.5
# 1180000 / 1416244.5
# 1190000 / 1416244.5
# 1200000 / 1416244.5
# 1210000 / 1416244.5
# 1220000 / 1416244.5
# 1230000 / 1416244.5
# 1240000 / 1416244.5
# 1250000 / 1416244.5
# 1260000 / 1416244.5
# 1270000 / 1416244.5
# 1280000 / 1416244.5
# 1290000 / 1416244.5
# 1300000 / 1416244.5
# 1310000 / 1416244.5
# 1320000 / 1416244.5
# 1330000 / 1416244.5
# 1340000 / 1416244.5
# 1350000 / 1416244.5
# 1360000 / 1416244.5
# 1370000 / 1416244.5
# 1380000 / 1416244.5
# 1390000 / 1416244.5
# 1400000 / 1416244.5
# 1410000 / 1416244.5

# %%
# load training set spectra
import spectrum

# %%
ms2_objects = spectrum.load_data_dir(spectra, spectra_folder, spectrum_filters.filter_by_frozen_dag)

# %%
ms_training_set_ids = []
ms_training_set_spectra = []
ms_training_set_metabolites = []

count = 0
for ms_object in ms2_objects:
    count += 1
    if count % 100 == 0:
        print('{} / {}, {} success'.format(count, len(ms2_objects), len(ms_training_set_metabolites)))
    try:
        metabolite_server.add_metabolite(ms_object.metabolite)
        success = True
    except:
        success = False
    if success:
        ms_training_set_metabolites.append(ms_object.metabolite)
        ms_training_set_spectra.append(ms_object.spectrum)
        ms_training_set_ids.append(ms_object.spectrum_id)
    
print('calculate kernel')
total = len(ms_training_set_ids) ** 2 / 2
count = 0
K_x = numpy.zeros((len(ms_training_set_ids), len(ms_training_set_ids)))
for v1_idx in range(len(ms_training_set_spectra)):
    for v2_idx in range(v1_idx + 1):
        count += 1
        if count % 10000 == 0:
            print('{} / {}'.format(count, total))
        v1 = ms_training_set_spectra[v1_idx]
        v2 = ms_training_set_spectra[v2_idx]
        k_v1_v2 = spectrum.ppk_wrapper(v1, v2)
        K_x[v1_idx, v2_idx] = k_v1_v2
        K_x[v2_idx, v1_idx] = k_v1_v2
# Out:
# 100 / 4138, 99 success
# 200 / 4138, 199 success
# 300 / 4138, 299 success
# 400 / 4138, 399 success
# 500 / 4138, 499 success
# 600 / 4138, 599 success
# 700 / 4138, 699 success
# 800 / 4138, 799 success
# 900 / 4138, 899 success
# 1000 / 4138, 999 success
# 1100 / 4138, 1099 success
# 1200 / 4138, 1199 success
# 1300 / 4138, 1299 success
# 1400 / 4138, 1399 success
# 1500 / 4138, 1499 success
# 1600 / 4138, 1599 success
# 1700 / 4138, 1699 success
# 1800 / 4138, 1799 success
# 1900 / 4138, 1899 success
# 2000 / 4138, 1999 success
# 2100 / 4138, 2099 success
# 2200 / 4138, 2199 success
# 2300 / 4138, 2299 success
# 2400 / 4138, 2399 success
# 2500 / 4138, 2499 success
# 2600 / 4138, 2599 success
# 2700 / 4138, 2699 success
# 2800 / 4138, 2799 success
# 2900 / 4138, 2899 success
# 3000 / 4138, 2999 success
# 3100 / 4138, 3099 success
# 3200 / 4138, 3199 success
# 3300 / 4138, 3299 success
# 3400 / 4138, 3399 success
# 3500 / 4138, 3499 success
# 3600 / 4138, 3599 success
# 3700 / 4138, 3699 success
# 3800 / 4138, 3799 success
# 3900 / 4138, 3899 success
# 4000 / 4138, 3999 success
# 4100 / 4138, 4099 success
# calculate kernel
# 10000 / 8561522.0
# 20000 / 8561522.0
# 30000 / 8561522.0
# 40000 / 8561522.0
# 50000 / 8561522.0
# 60000 / 8561522.0
# 70000 / 8561522.0
# 80000 / 8561522.0
# 90000 / 8561522.0
# 100000 / 8561522.0
# 110000 / 8561522.0
# 120000 / 8561522.0
# 130000 / 8561522.0
# 140000 / 8561522.0
# 150000 / 8561522.0
# 160000 / 8561522.0
# 170000 / 8561522.0
# 180000 / 8561522.0
# 190000 / 8561522.0
# 200000 / 8561522.0
# 210000 / 8561522.0
# 220000 / 8561522.0
# 230000 / 8561522.0
# 240000 / 8561522.0
# 250000 / 8561522.0
# 260000 / 8561522.0
# 270000 / 8561522.0
# 280000 / 8561522.0
# 290000 / 8561522.0
# 300000 / 8561522.0
# 310000 / 8561522.0
# 320000 / 8561522.0
# 330000 / 8561522.0
# 340000 / 8561522.0
# 350000 / 8561522.0
# 360000 / 8561522.0
# 370000 / 8561522.0
# 380000 / 8561522.0
# 390000 / 8561522.0
# 400000 / 8561522.0
# 410000 / 8561522.0
# 420000 / 8561522.0
# 430000 / 8561522.0
# 440000 / 8561522.0
# 8260000 / 8561522.0
# 8270000 / 8561522.0
# 8280000 / 8561522.0
# 8290000 / 8561522.0
# 8300000 / 8561522.0
# 8310000 / 8561522.0
# 8320000 / 8561522.0
# 8330000 / 8561522.0
# 8340000 / 8561522.0
# 8350000 / 8561522.0
# 8360000 / 8561522.0
# 8370000 / 8561522.0
# 8380000 / 8561522.0
# 8390000 / 8561522.0
# 8400000 / 8561522.0
# 8410000 / 8561522.0
# 8420000 / 8561522.0
# 8430000 / 8561522.0
# 8440000 / 8561522.0
# 8450000 / 8561522.0
# 8460000 / 8561522.0
# 8470000 / 8561522.0
# 8480000 / 8561522.0
# 8490000 / 8561522.0
# 8500000 / 8561522.0
# 8510000 / 8561522.0
# 8520000 / 8561522.0
# 8530000 / 8561522.0
# 8540000 / 8561522.0
# 8550000 / 8561522.0
# 8560000 / 8561522.0

# %%
import molecular_fingerprints

# %%
K_y = numpy.zeros((len(ms_training_set_ids), len(bgc_training_set_ids)))

total = len(ms_training_set_ids) * len(bgc_training_set_ids)
count = 0
for i in range(len(ms_training_set_ids)):
    for j in range(len(bgc_training_set_ids)):
        count += 1
        if count % 10000 == 0:
            print('{} / {}'.format(count, total))
        structure_1 = ms_training_set_metabolites[i]
        structure_2 = bgc_training_set_metabolites[j]
        fp1 = metabolite_server.get_metabolite(structure_1)['fingerprint']
        fp2 = metabolite_server.get_metabolite(structure_2)['fingerprint']
        k_fp1_fp2 = molecular_fingerprints.fingerprint_kernel(fp1, fp2)
        K_y[i, j] = k_fp1_fp2
# Out:
# 10000 / 6964254
# 20000 / 6964254
# 30000 / 6964254
# 40000 / 6964254
# 50000 / 6964254
# 60000 / 6964254
# 70000 / 6964254
# 80000 / 6964254
# 90000 / 6964254
# 100000 / 6964254
# 110000 / 6964254
# 120000 / 6964254
# 130000 / 6964254
# 140000 / 6964254
# 150000 / 6964254
# 160000 / 6964254
# 170000 / 6964254
# 180000 / 6964254
# 190000 / 6964254
# 200000 / 6964254
# 210000 / 6964254
# 220000 / 6964254
# 230000 / 6964254
# 240000 / 6964254
# 250000 / 6964254
# 260000 / 6964254
# 270000 / 6964254
# 280000 / 6964254
# 290000 / 6964254
# 300000 / 6964254
# 310000 / 6964254
# 320000 / 6964254
# 330000 / 6964254
# 340000 / 6964254
# 350000 / 6964254
# 360000 / 6964254
# 370000 / 6964254
# 380000 / 6964254
# 390000 / 6964254
# 400000 / 6964254
# 410000 / 6964254
# 420000 / 6964254
# 430000 / 6964254
# 440000 / 6964254
# 450000 / 6964254
# 460000 / 6964254
# 470000 / 6964254
# 480000 / 6964254
# 490000 / 6964254
# 500000 / 6964254
# 510000 / 6964254
# 520000 / 6964254
# 530000 / 6964254
# 540000 / 6964254
# 550000 / 6964254
# 560000 / 6964254
# 570000 / 6964254
# 580000 / 6964254
# 590000 / 6964254
# 600000 / 6964254
# 610000 / 6964254
# 620000 / 6964254
# 630000 / 6964254
# 640000 / 6964254
# 650000 / 6964254
# 660000 / 6964254
# 670000 / 6964254
# 680000 / 6964254
# 690000 / 6964254
# 700000 / 6964254
# 5910000 / 6964254
# 5920000 / 6964254
# 5930000 / 6964254
# 5940000 / 6964254
# 5950000 / 6964254
# 5960000 / 6964254
# 5970000 / 6964254
# 5980000 / 6964254
# 5990000 / 6964254
# 6000000 / 6964254
# 6010000 / 6964254
# 6020000 / 6964254
# 6030000 / 6964254
# 6040000 / 6964254
# 6050000 / 6964254
# 6060000 / 6964254
# 6070000 / 6964254
# 6080000 / 6964254
# 6090000 / 6964254
# 6100000 / 6964254
# 6110000 / 6964254
# 6120000 / 6964254
# 6130000 / 6964254
# 6140000 / 6964254
# 6150000 / 6964254
# 6160000 / 6964254
# 6170000 / 6964254
# 6180000 / 6964254
# 6190000 / 6964254
# 6200000 / 6964254
# 6210000 / 6964254
# 6220000 / 6964254
# 6230000 / 6964254
# 6240000 / 6964254
# 6250000 / 6964254
# 6260000 / 6964254
# 6270000 / 6964254
# 6280000 / 6964254
# 6290000 / 6964254
# 6300000 / 6964254
# 6310000 / 6964254
# 6320000 / 6964254
# 6330000 / 6964254
# 6340000 / 6964254
# 6350000 / 6964254
# 6360000 / 6964254
# 6370000 / 6964254
# 6380000 / 6964254
# 6390000 / 6964254
# 6400000 / 6964254
# 6410000 / 6964254
# 6420000 / 6964254
# 6430000 / 6964254
# 6440000 / 6964254
# 6450000 / 6964254
# 6460000 / 6964254
# 6470000 / 6964254
# 6480000 / 6964254
# 6490000 / 6964254
# 6500000 / 6964254
# 6510000 / 6964254
# 6520000 / 6964254
# 6530000 / 6964254
# 6540000 / 6964254
# 6550000 / 6964254
# 6560000 / 6964254
# 6570000 / 6964254
# 6580000 / 6964254
# 6590000 / 6964254
# 6600000 / 6964254
# 6610000 / 6964254
# 6620000 / 6964254
# 6630000 / 6964254
# 6640000 / 6964254
# 6650000 / 6964254
# 6660000 / 6964254
# 6670000 / 6964254
# 6680000 / 6964254
# 6690000 / 6964254
# 6700000 / 6964254
# 6710000 / 6964254
# 6720000 / 6964254
# 6730000 / 6964254
# 6740000 / 6964254
# 6750000 / 6964254
# 6760000 / 6964254
# 6770000 / 6964254
# 6780000 / 6964254
# 6790000 / 6964254
# 6800000 / 6964254
# 6810000 / 6964254
# 6820000 / 6964254
# 6830000 / 6964254
# 6840000 / 6964254
# 6850000 / 6964254
# 6860000 / 6964254
# 6870000 / 6964254
# 6880000 / 6964254
# 6890000 / 6964254
# 6900000 / 6964254
# 6910000 / 6964254
# 6920000 / 6964254
# 6930000 / 6964254
# 6940000 / 6964254
# 6950000 / 6964254
# 6960000 / 6964254

# %%
# Create mechanism to build the test sample kernel vectors

# %%
import iokr_data_server

# %%
data_server = iokr_data_server.IOKRDataServer()

# %%
data_server.data_set_x = ms_training_set_spectra
data_server.data_set_x_ids = ms_training_set_ids
data_server.kernel_function_x = spectrum.ppk_wrapper
data_server.K_x = K_x

data_server.K_y = K_y

data_server.data_set_z = bgc_training_set_wv
data_server.data_set_z_ids = bgc_training_set_ids
data_server.kernel_function_z = bgc.wv_kernel
data_server.K_z = K_z

data_server.data_type_x = type(ms_training_set_spectra[0])
data_server.data_type_z = type(bgc_training_set_wv[0])

# %%
# init IOKR server

# %%
import iokr_server

# %%
iokr = iokr_server.IOKRServer()

iokr._lambda = 0.1

iokr.training_data_x = ms_training_set_spectra
iokr.training_data_z = bgc_training_set_wv

iokr.K_x = K_x
iokr.K_y = K_y
iokr.K_z = K_z

iokr.init()

# %%
# test_set_bgcs
# test_set_spectra
# established_link_objects_ids
import time

# %%
score_matrix = numpy.zeros((len(test_set_spectra), len(test_set_bgcs)))
count = 0
total = len(test_set_spectra) * len(test_set_bgcs)
K_x_inv = iokr.K_x_inv
K_y = iokr.K_y
K_z_inv = iokr.K_z_inv
t0 = time.time()
for s_idx, (s_obj, s_id) in enumerate(test_set_spectra):
    s_id = str(s_id)
    x_kernel_vector = data_server.kernel_vector(s_obj, s_id)
    for b_idx, (b_obj, b_id) in enumerate(test_set_bgcs):
        count += 1
        if count % 1000 == 0:
            remaining = total - count
            t1 = time.time()
            time_per_sample = (t1 - t0) / 1000
            projected_time_sec = remaining * time_per_sample
            projected_min = projected_time_sec / 60
            projected_hrs = projected_min / 60
            projected_days = projected_hrs / 24
            #print(projected_time_sec)
            print('{} / {}, projected {} days, {}:{}'.format(
                count, 
                total, 
                int(projected_days), 
                int(projected_hrs) % 24, 
                int(projected_min) % 60))
            t0 = time.time()
        z_kernel_vector = data_server.kernel_vector(b_obj, b_id)

        score = iokr_server.score_vector(x_kernel_vector, z_kernel_vector, K_x_inv, K_y, K_z_inv)
        score_matrix[s_idx, b_idx] = score
# Out:
# 1000 / 25431, projected 0 days, 0:34
# 2000 / 25431, projected 0 days, 0:6
# 3000 / 25431, projected 0 days, 0:6
# 4000 / 25431, projected 0 days, 0:5
# 5000 / 25431, projected 0 days, 0:5
# 6000 / 25431, projected 0 days, 0:5
# 7000 / 25431, projected 0 days, 0:5
# 8000 / 25431, projected 0 days, 0:4
# 9000 / 25431, projected 0 days, 0:4
# 10000 / 25431, projected 0 days, 0:3
# 11000 / 25431, projected 0 days, 0:3
# 12000 / 25431, projected 0 days, 0:3
# 13000 / 25431, projected 0 days, 0:3
# 14000 / 25431, projected 0 days, 0:2
# 15000 / 25431, projected 0 days, 0:2
# 16000 / 25431, projected 0 days, 0:2
# 17000 / 25431, projected 0 days, 0:2
# 18000 / 25431, projected 0 days, 0:1
# 19000 / 25431, projected 0 days, 0:1
# 20000 / 25431, projected 0 days, 0:1
# 21000 / 25431, projected 0 days, 0:1
# 22000 / 25431, projected 0 days, 0:0
# 23000 / 25431, projected 0 days, 0:0
# 24000 / 25431, projected 0 days, 0:0
# 25000 / 25431, projected 0 days, 0:0

# %%
import pickle
with open('leao_full_iokr.bin', 'wb') as f:
    pickle.dump(score_matrix, f)

# %%
# test_set_spectra = s_obj, s_id
# test_set_bgc = b_obj, b_id
# score = score_matrix[spectrum_idx, bgc_idx]

# %%
import numpy

# %%
established_bgc_names = [x[0] for x in established_link_objects_ids]
established_spectra_ids = [x[1] for x in established_link_objects_ids]
count = 0
gcf_mf_validated = set([])
for g in npl.gcfs:
    for b in g.bgcs:
        for m in npl.molfams:
            for s in m.spectra:
                if (b.name, s.spectrum_id) in established_link_objects_ids:
                    gcf_mf_validated.add((g.id, m.id))
                    count += 1
print(count)
print(gcf_mf_validated)
print(len(gcf_mf_validated))
# Out:
# 8
# {(75, 7), (70, 7), (29, 29), (28, 16), (14, 7), (40, 20), (23, 21), (33, 29)}
# 8

# %%
test_set_bgc_ids = [x[1] for x in test_set_bgcs]
test_set_spectra_ids = [x[1] for x in test_set_spectra]

iokr_scores_all = []
iokr_scores_validated = []

count = 0
for g in npl.gcfs:
    for m in npl.molfams:
        count += 1
        if count % 1000 == 0:
            print("{} / {}".format(count, len(npl.gcfs) * len(npl.molfams)))
        link_score = -100
        for b in g.bgcs:
            b_idx = test_set_bgc_ids.index(b.name)
            for s in m.spectra:
                s_idx = test_set_spectra_ids.index(s.spectrum_id)
                score = score_matrix[s_idx, b_idx]
                link_score = max(score, link_score)
        iokr_scores_all.append(link_score)
        # validated
        if (g.id, m.id) in gcf_mf_validated:
            iokr_scores_validated.append(link_score)
# Out:
# 1000 / 9900
# 2000 / 9900
# 3000 / 9900
# 4000 / 9900
# 5000 / 9900
# 6000 / 9900
# 7000 / 9900
# 8000 / 9900
# 9000 / 9900

# %%
len(iokr_scores_validated)
# Out:
# 8

# %%
perc = numpy.percentile(iokr_scores_all, 95)
percentile_size = len([x for x in iokr_scores_all if x > perc])
percentile_validated_size = len([x for x in iokr_scores_validated if x > perc])
print('all:', len(iokr_scores_validated) / len(iokr_scores_all))
print('perc:', percentile_validated_size / percentile_size)
# Out:
# all: 0.0008080808080808081
# perc: 0.006060606060606061

# %%
import scipy

# %%
print('total size:', len(iokr_scores_all))
print('valid size:', len(iokr_scores_validated))
print('perc size:', percentile_size)
print('valid perc size:', percentile_validated_size)
contingency_table = numpy.array([
    [len(iokr_scores_all), len(iokr_scores_validated)],
    [percentile_size, percentile_validated_size]
])
print('p-val:', scipy.stats.fisher_exact(contingency_table))
# Out:
# total size: 9900
# valid size: 8
# perc size: 495
# valid perc size: 3
# p-val: (7.5, 0.013479211564772492)

# %%
perc = numpy.percentile(iokr_scores_all, 90)
percentile_size = len([x for x in iokr_scores_all if x > perc])
percentile_validated_size = len([x for x in iokr_scores_validated if x > perc])
print('all:', len(iokr_scores_validated) / len(iokr_scores_all))
print('perc:', percentile_validated_size / percentile_size)
# Out:
# all: 0.0008080808080808081
# perc: 0.0030303030303030303

# %%
print('total size:', len(iokr_scores_all))
print('valid size:', len(iokr_scores_validated))
print('perc size:', percentile_size)
print('valid perc size:', percentile_validated_size)
contingency_table = numpy.array([
    [len(iokr_scores_all), len(iokr_scores_validated)],
    [percentile_size, percentile_validated_size]
])
print('p-val:', scipy.stats.fisher_exact(contingency_table))
# Out:
# total size: 9900
# valid size: 8
# perc size: 990
# valid perc size: 3
# p-val: (3.75, 0.0714460980777989)

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set()

# %%
fig = plt.figure(figsize=(8, 6))


# ax_min = -0.15
ax_min = -0.25
# ax_max = 0.35
ax_max = 1.0

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('Leao')

ax1.hist(iokr_scores_all, bins=50, range=[ax_min, ax_max])

ax2.plot(iokr_scores_validated, [5000]*len(iokr_scores_validated), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

plt.savefig('combined_iokr_hist_leao.pdf')
# Out:
# /home/grimur/miniconda2/envs/jupyter-py3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# Complementarity of scores

# %%
from nplinker.scoring import misc

# %%
strains = npl.strains

# %%
test_set_bgc_ids = [x[1] for x in test_set_bgcs]
test_set_spectra_ids = [x[1] for x in test_set_spectra]

iokr_scores_all = []
iokr_scores_validated = []
corr_scores_all = []
corr_scores_validated = []

count = 0
for g in npl.gcfs:
    for m in npl.molfams:
        count += 1
        if count % 1000 == 0:
            print("{} / {}".format(count, len(npl.gcfs) * len(npl.molfams)))
        link_score = -100
        for b in g.bgcs:
            b_idx = test_set_bgc_ids.index(b.name)
            for s in m.spectra:
                s_idx = test_set_spectra_ids.index(s.spectrum_id)
                score = score_matrix[s_idx, b_idx]
                link_score = max(score, link_score)
        iokr_scores_all.append(link_score)
        corr_score = misc.metcalf_scoring(m, g, strains, standardised=True)
        corr_scores_all.append(corr_score)
        # validated
        if (g.id, m.id) in gcf_mf_validated:
            iokr_scores_validated.append(link_score)
            corr_scores_validated.append(corr_score)
# Out:
# 1000 / 9900
# 2000 / 9900
# 3000 / 9900
# 4000 / 9900
# 5000 / 9900
# 6000 / 9900
# 7000 / 9900
# 8000 / 9900
# 9000 / 9900

# %%
# Fig. for SI

all_score_pairs = list(zip(corr_scores_all, iokr_scores_all))
verified_score_pairs = list(zip(corr_scores_validated, iokr_scores_validated))

col1 = [x[0] for x in all_score_pairs if x[1] != -100]
col2 = [x[1] for x in all_score_pairs if x[1] != -100]


plot = sns.jointplot(col1, col2, alpha=0.1, ratio=2, height=12, marginal_kws={'hist_kws': {'alpha': 0.5}})
plot.ax_joint.plot([x[0] for x in verified_score_pairs if x[1] != -100], [x[1] for x in verified_score_pairs if x[1] != -100], 'ro', color='r')
# bc horizontal, flip x and y axis
plot.ax_marg_y.plot([0]*len(iokr_scores_validated), iokr_scores_validated, '|', color='k', marker=(2, 0, 90), markersize=50)
plot.ax_marg_x.plot(corr_scores_validated, [0]*len(corr_scores_validated), '|', color='k', markersize=50)


#plot.set_axis_labels('Standardised strain correlation score', 'IOKR score', size='large')
plot.set_axis_labels('Strain correlation score', 'IOKR score')


filename = '20210604_graph_combined_data_iokr_metcalf_leao'
plot.savefig(filename + '.png') #, dpi=1200)

# %%
# Validated links above 90 and 95 percentile

# %%
percentile_cutoff = 90

all_score_pairs = list(zip(corr_scores_all, iokr_scores_all))
verified_score_pairs = list(zip(corr_scores_validated, iokr_scores_validated))

iokr_percentile = numpy.percentile(iokr_scores_all, percentile_cutoff)
corr_percentile = numpy.percentile(corr_scores_all, percentile_cutoff)

iokr_valid_top = len([x for x in iokr_scores_validated if x >= iokr_percentile])
iokr_all_top = len([x for x in iokr_scores_all if x >= iokr_percentile])

corr_valid_top = len([x for x in corr_scores_validated if x >= corr_percentile])
corr_all_top = len([x for x in corr_scores_all if x >= corr_percentile])

both_valid_top = len([x for x, y in verified_score_pairs if x >= corr_percentile and y >= iokr_percentile])
both_all_top = len([x for x, y in all_score_pairs if x >= corr_percentile and y >= iokr_percentile])

print('all verified {}'.format(len(verified_score_pairs)))
print('all total {}'.format(len(all_score_pairs)))
print('all ratio {}'.format(len(verified_score_pairs) / len(all_score_pairs)))
print('iokr verified {}'.format(iokr_valid_top))
print('iokr total {}'.format(iokr_all_top))
print('iokr ratio {}'.format(iokr_valid_top / iokr_all_top))
print('corr verified {}'.format(corr_valid_top))
print('corr total {}'.format(corr_all_top))
print('corr ratio {}'.format(corr_valid_top / corr_all_top))
print('both verified {}'.format(both_valid_top))
print('both total {}'.format(both_all_top))
print('both ratio {}'.format(both_valid_top / both_all_top))
# Out:
# all verified 8
# all total 9900
# all ratio 0.0008080808080808081
# iokr verified 3
# iokr total 990
# iokr ratio 0.0030303030303030303
# corr verified 5
# corr total 1493
# corr ratio 0.003348961821835231
# both verified 1
# both total 172
# both ratio 0.005813953488372093

# %%
percentile_cutoff = 95

all_score_pairs = list(zip(corr_scores_all, iokr_scores_all))
verified_score_pairs = list(zip(corr_scores_validated, iokr_scores_validated))

iokr_percentile = numpy.percentile(iokr_scores_all, percentile_cutoff)
corr_percentile = numpy.percentile(corr_scores_all, percentile_cutoff)

iokr_valid_top = len([x for x in iokr_scores_validated if x >= iokr_percentile])
iokr_all_top = len([x for x in iokr_scores_all if x >= iokr_percentile])

corr_valid_top = len([x for x in corr_scores_validated if x >= corr_percentile])
corr_all_top = len([x for x in corr_scores_all if x >= corr_percentile])

both_valid_top = len([x for x, y in verified_score_pairs if x >= corr_percentile and y >= iokr_percentile])
both_all_top = len([x for x, y in all_score_pairs if x >= corr_percentile and y >= iokr_percentile])

print('all verified {}'.format(len(verified_score_pairs)))
print('all total {}'.format(len(all_score_pairs)))
print('all ratio {}'.format(len(verified_score_pairs) / len(all_score_pairs)))
print('iokr verified {}'.format(iokr_valid_top))
print('iokr total {}'.format(iokr_all_top))
print('iokr ratio {}'.format(iokr_valid_top / iokr_all_top))
print('corr verified {}'.format(corr_valid_top))
print('corr total {}'.format(corr_all_top))
if corr_all_top != 0:
    print('corr ratio {}'.format(corr_valid_top / corr_all_top))
else:
    print('corr ratio 0')
print('both verified {}'.format(both_valid_top))
print('both total {}'.format(both_all_top))
if both_all_top != 0:
    print('both ratio {}'.format(both_valid_top / both_all_top))
else:
    print('both ratio 0')
# Out:
# all verified 8
# all total 9900
# all ratio 0.0008080808080808081
# iokr verified 3
# iokr total 495
# iokr ratio 0.006060606060606061
# corr verified 5
# corr total 1493
# corr ratio 0.003348961821835231
# both verified 1
# both total 72
# both ratio 0.013888888888888888
